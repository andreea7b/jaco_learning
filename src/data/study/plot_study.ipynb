# %%
import numpy as np
import glob
import pickle 
import csv
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab
import matplotlib
# %matplotlib inline
from scipy import stats  
import seaborn as sns
from matplotlib.lines import Line2D
import scipy as sp

# %%
#matplotlib.rcParams['text.usetex'] = True
matplotlib.rc('font',family='serif', serif=['Palatino'])
sns.set_style('white')

pgf_with_rc_fonts = {"pgf.texsystem": "pdflatex"}
matplotlib.rcParams.update(pgf_with_rc_fonts)

def set_style():
    sns.set(font='serif', font_scale=1.4)
    
   # Make the background white, and specify the
    # specific font family
    sns.set_style("white", {
        "font.family": "serif",
        "font.weight": "normal",
        "font.serif": ["Times", "Palatino", "serif"],
        'axes.facecolor': 'white',
        'lines.markeredgewidth': 1})

# %%
def plot_sig_line(ax, x1, x2, y1, h, padding=0.3):
    '''
    Plots the bracket thing denoting significance in plots. h controls how tall vertically the bracket is.
    Only need one y coordinate (y1) since the bracket is parallel to the x-axis.
    '''
    ax.plot([x1, x1, x2, x2], [y1, y1 + h, y1 + h, y1], linewidth=1, color='k')
    ax.text(0.5*(x1 + x2), y1 + h + padding * h, '*', color='k', fontsize=16, fontweight='normal')

# %%
obj_df = pd.read_csv('metrics_obj.csv')
subj_df = pd.read_csv('metrics_subj.csv')

# %%
cost_opt_1 = obj_df.loc[(obj_df['task'] == 'T1')]['Rfeat*']
cost_opt_2 = obj_df.loc[(obj_df['task'] == 'T2')]['Rfeat*']
cost_opt_3 = obj_df.loc[(obj_df['task'] == 'T3')]['Rfeat*']
cost_opt_4 = obj_df.loc[(obj_df['task'] == 'T4')]['Rfeat*']

cost_A_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'A')]['Rfeat']
cost_A_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'A')]['Rfeat']
cost_A_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'A')]['Rfeat']
cost_A_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'A')]['Rfeat']

cost_B_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'B')]['Rfeat']
cost_B_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'B')]['Rfeat']
cost_B_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'B')]['Rfeat']
cost_B_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'B')]['Rfeat']

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig, ax1 = plt.subplots()

set_style()
A_color = '#cccccc'
B_color = '#f79646'
desired_color = '#008080'

##### Table #####
ax1.set_title('Average Cost Across Tasks', fontsize=16, fontweight='normal')
r1 = ax1.bar([0.0], 
             [cost_A_1.mean()], 
             yerr=[cost_A_1.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [cost_B_1.mean()], 
             yerr=[cost_B_1.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r3 = ax1.bar([2.0], 
             [cost_opt_1.mean()], 
             yerr=[cost_opt_1.sem()], 
             color=[desired_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r4 = ax1.bar([4.0], 
             [cost_A_2.mean()], 
             yerr=[cost_A_2.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r5 = ax1.bar([5.0], 
             [cost_B_2.mean()], 
             yerr=[cost_B_2.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r6 = ax1.bar([6.0], 
             [cost_opt_2.mean()], 
             yerr=[cost_opt_2.sem()], 
             color=[desired_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r7 = ax1.bar([8.0], 
             [cost_A_3.mean()], 
             yerr=[cost_A_3.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r8 = ax1.bar([9.0], 
             [cost_B_3.mean()], 
             yerr=[cost_B_3.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r9 = ax1.bar([10.0], 
             [cost_opt_3.mean()], 
             yerr=[cost_opt_3.sem()], 
             color=[desired_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r10 = ax1.bar([12.0], 
             [cost_A_4.mean()], 
             yerr=[cost_A_4.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r11 = ax1.bar([13.0], 
             [cost_B_4.mean()], 
             yerr=[cost_B_4.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r12 = ax1.bar([14.0], 
             [cost_opt_4.mean()], 
             yerr=[cost_opt_4.sem()], 
             color=[desired_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

#plot_sig_line(ax1, 0, 1, 1.65, 0.08)
ax1.set_ylim([0, 130])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([1,5,9,13], ["Task 1", "Task 2", "Task 3", "Task 4"])
ax1.set_ylabel('Cost Value', fontsize=16, fontweight='normal')
################

leg = ax1.legend((r1[0], r2[0], r3[0]), 
                (r'Fixed $\beta$', r'Adaptive $\beta$', 'Desired'), 
                loc='upper right',
                ncol=1, 
                fontsize=11,
                bbox_to_anchor=(1., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(8)
fig.set_figheight(4)

plt.savefig('average_cost_barplots.pdf', bbox_inches='tight')

# %%
Dcost_A_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'A')]['RfD']
Dcost_A_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'A')]['RfD']
Dcost_A_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'A')]['RfD']
Dcost_A_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'A')]['RfD']

Dcost_B_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'B')]['RfD']
Dcost_B_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'B')]['RfD']
Dcost_B_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'B')]['RfD']
Dcost_B_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'B')]['RfD']

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

fig, ax1 = plt.subplots()

set_style()
A_color = '#cccccc'
B_color = '#f79646'
desired_color = '#008080'

##### Table #####
#ax1.set_title('Average Regret Across Subjects', fontsize=18, fontweight='normal')
r1 = ax1.bar([0.0], 
             [Dcost_A_1.mean()], 
             yerr=[Dcost_A_1.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [Dcost_B_1.mean()], 
             yerr=[Dcost_B_1.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r3 = ax1.bar([3.0], 
             [Dcost_A_2.mean()], 
             yerr=[Dcost_A_2.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r4 = ax1.bar([4.0], 
             [Dcost_B_2.mean()], 
             yerr=[Dcost_B_2.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r5 = ax1.bar([6.0], 
             [Dcost_A_3.mean()], 
             yerr=[Dcost_A_3.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r6 = ax1.bar([7.0], 
             [Dcost_B_3.mean()], 
             yerr=[Dcost_B_3.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r7 = ax1.bar([9.0], 
             [Dcost_A_4.mean()], 
             yerr=[Dcost_A_4.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r8 = ax1.bar([10.0], 
             [Dcost_B_4.mean()], 
             yerr=[Dcost_B_4.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

plot_sig_line(ax1, 3, 4, 100, 2)
plot_sig_line(ax1, 9, 10, 25, 2)
ax1.set_ylim([0, 110])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([0.5,3.5,6.5,9.5],[r"$Table_{r=1}$", r"$Table_{r=0}$", r"$Coffee_{r=1}$", r"$Coffee_{r=0}$"])
ax1.set_ylabel('Regret', fontsize=16, fontweight='normal')
################

leg = ax1.legend((r1[0], r2[0]), 
                (r'Fixed $\beta$', r'Inferred $\beta$'), 
                loc='upper right',
                ncol=1, 
                fontsize=14,
                bbox_to_anchor=(1., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(8)
fig.set_figheight(4)

plt.savefig('average_delta_cost_barplots.pdf', bbox_inches='tight')

# %%
WP_A_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'A')]['WeightPath']
WP_A_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'A')]['WeightPath']
WP_A_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'A')]['WeightPath']
WP_A_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'A')]['WeightPath']

WP_B_1 = obj_df.loc[(obj_df['task'] == 'T1')&(obj_df['method'] == 'B')]['WeightPath']
WP_B_2 = obj_df.loc[(obj_df['task'] == 'T2')&(obj_df['method'] == 'B')]['WeightPath']
WP_B_3 = obj_df.loc[(obj_df['task'] == 'T3')&(obj_df['method'] == 'B')]['WeightPath']
WP_B_4 = obj_df.loc[(obj_df['task'] == 'T4')&(obj_df['method'] == 'B')]['WeightPath']

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

fig, ax1 = plt.subplots()

set_style()
A_color = '#cccccc'
B_color = '#f79646'
desired_color = '#008080'

##### Table #####
#ax1.set_title(r'Average Learning Path Length of $\hat{\theta}$', fontsize=18, fontweight='normal')
r1 = ax1.bar([0.0], 
             [WP_A_1.mean()], 
             yerr=[WP_A_1.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [WP_B_1.mean()], 
             yerr=[WP_B_1.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r3 = ax1.bar([3.0], 
             [WP_A_2.mean()], 
             yerr=[WP_A_2.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r4 = ax1.bar([4.0], 
             [WP_B_2.mean()], 
             yerr=[WP_B_2.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r5 = ax1.bar([6.0], 
             [WP_A_3.mean()], 
             yerr=[WP_A_3.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r6 = ax1.bar([7.0], 
             [WP_B_3.mean()], 
             yerr=[WP_B_3.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

r7 = ax1.bar([9.0], 
             [WP_A_4.mean()], 
             yerr=[WP_A_4.sem()], 
             color=[A_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r8 = ax1.bar([10.0], 
             [WP_B_4.mean()], 
             yerr=[WP_B_4.sem()], 
             color=[B_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))

plot_sig_line(ax1, 3, 4, 1.7, 0.1)
plot_sig_line(ax1, 9, 10, 3.2, 0.1)
ax1.set_ylim([0, 5])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([0.5,3.5,6.5,9.5],[r"$Table_{r=1}$", r"$Table_{r=0}$", r"$Coffee_{r=1}$", r"$Coffee_{r=0}$"])
ax1.set_ylabel('Learning Path Length', fontsize=16, fontweight='normal')
################

leg = ax1.legend((r1[0], r2[0]), 
                (r'Fixed $\beta$', r'Inferred $\beta$'), 
                loc='upper right',
                ncol=1, 
                fontsize=14,
                bbox_to_anchor=(1., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(8)
fig.set_figheight(4)

plt.savefig('average_weight_path_barplots.pdf', bbox_inches='tight')
