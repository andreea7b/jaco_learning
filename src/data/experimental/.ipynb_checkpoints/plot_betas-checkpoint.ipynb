# %%
import numpy as np
import glob
import pickle 
import csv
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab
import matplotlib
# %matplotlib inline
from scipy import stats  
import seaborn as sns
from matplotlib.lines import Line2D
import scipy as sp

# %%
#matplotlib.rcParams['text.usetex'] = True
matplotlib.rc('font',family='serif', serif=['Palatino'])
sns.set_style('white')

pgf_with_rc_fonts = {"pgf.texsystem": "pdflatex"}
matplotlib.rcParams.update(pgf_with_rc_fonts)

def set_style():
    sns.set(font='serif', font_scale=1.4)
    
   # Make the background white, and specify the
    # specific font family
    sns.set_style("white", {
        "font.family": "serif",
        "font.weight": "normal",
        "font.serif": ["Times", "Palatino", "serif"],
        'axes.facecolor': 'white',
        'lines.markeredgewidth': 1})

# %%
def plot_sig_line(ax, x1, x2, y1, h, padding=0.3):
    '''
    Plots the bracket thing denoting significance in plots. h controls how tall vertically the bracket is.
    Only need one y coordinate (y1) since the bracket is parallel to the x-axis.
    '''
    ax.plot([x1, x1, x2, x2], [y1, y1 + h, y1 + h, y1], linewidth=1, color='k')
    ax.text(0.5*(x1 + x2), y1 + h + padding * h, '*', color='k', fontsize=16, fontweight='normal')

# %%
person_names = {0: "Andreea", 1: "Andrea", 2: "Eli", 3: "Ravi", 4: "Hong", 5: "Ellis", 6: "Steven", 7:"Smitha", 8:"Simon", 9:"Erin", 10:"Mitch", 11:"Elizabeth"}
corrections_str = []
for file in glob.glob('betas/*_BETA_*.p'):
    corrections_str.append(file)
    
csv_table = [["Name", "Features known by R", "Features corrected by H", "Rational", "Correction #", "Timestamp", "Update", "Beta1", "Beta2", "Beta3"]]
    
for file_path in corrections_str:
    # Parse string to find features known and features corrected
    print "Parsing this file:", file_path
    str_list = file_path.split("_")
    method_idx = str_list.index("BETA")
    correction_idx = str_list.index("correction")
    end_idx = len(str_list)-1
    
    person_ID = person_names[int(str_list[1])]
    features_known = str_list[method_idx+1:correction_idx]
    features_corrected = str_list[correction_idx+1:-1]
    is_rational = not set(features_known).isdisjoint(features_corrected)
            
    features_known_str = ",".join(features_known)
    features_corrected_str = ",".join(features_corrected)
    
    print "Name of human:", person_ID
    print "Robot knew about these features:", features_known
    print "Human was asked to correct these features:", features_corrected  
    print "Was human rational?", is_rational
    betas = pickle.load(open(file_path, "rb"))
    if betas is None:
        continue
    timestamp = betas[:,0]
    betas = betas[:,1:]
    print "Timestamp of pushes:", timestamp
    print "Beta values:", betas
  
    # Look at update data
    update_str = "updates/updates_" + ('_').join(str_list[1:])
    updates = pickle.load(open(update_str, "rb"))
    updates = updates[:,1:]
    print "Updates:", updates, "\n"
    
    # Create csv data
    csv_row = [person_ID, features_known_str[:], features_corrected_str[:]]

    for i in range(len(timestamp)):
        is_rational_i = is_rational
        if is_rational:
            if 'table' in features_corrected:
                feat_idx = features_known.index('table')
                if updates[i,feat_idx] > -0.1:
                    is_rational_i = False
            if 'coffee' in features_corrected:
                feat_idx = features_known.index('coffee')
                if updates[i,feat_idx] > -0.1:
                    is_rational_i = False
            if 'human' in features_corrected:
                feat_idx = features_known.index('human')
                if updates[i,feat_idx] > -0.1:
                    is_rational_i = False
        csv_row_current = csv_row + [is_rational_i, i, timestamp[i]] + [updates[i,].tolist()] + betas[i,:].tolist() + [float('nan')]*(3-len(betas[i,:]))
        csv_table.append(csv_row_current)
    
csv_file = open('beta_pilot.csv', 'w')
with csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(csv_table)
    
df = pd.DataFrame(data=csv_table[:][1:], columns=csv_table[:][0])
# Out:
# Parsing this file: betas/betas_1_B_BETA_human_correction_accident_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.64570308  9.85766697]
# Beta values: [[ 0.04988554]
#  [ 0.20730106]]
# Updates: [[-0.21464616]
#  [ 1.08244706]]
#
# Parsing this file: betas/betas_7_B_BETA_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 7.84293389]
# Beta values: [[ 0.61597337]]
# Updates: [[-0.57748885]]
#
# Parsing this file: betas/betas_6_B_BETA_table_coffee_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.49922204]
# Beta values: [[ 0.04720027  0.00103463]]
# Updates: [[-0.15733646 -0.04953888]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_human_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.09294295  4.76658201  5.42512703]
# Beta values: [[ 0.02788572]
#  [ 0.00686173]
#  [ 0.00982675]]
# Updates: [[-0.16043026]
#  [-0.14640746]
#  [ 0.05516381]]
#
# Parsing this file: betas/betas_6_B_BETA_human_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [  8.01034808  10.43267798  11.04193211  11.64574313  14.83260202]
# Beta values: [[ 0.5772626]
#  [ 0.       ]
#  [ 0.       ]
#  [ 0.       ]
#  [ 0.       ]]
# Updates: [[-3.658369]
#  [ 0.      ]
#  [ 0.      ]
#  [ 0.      ]
#  [ 0.      ]]
#
# Parsing this file: betas/betas_7_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 18.11833286]
# Beta values: [[ 0.27767115  0.00398773  1.70613207]]
# Updates: [[-0.1781826   0.05660246 -0.54677858]]
#
# Parsing this file: betas/betas_7_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 5.15978503]
# Beta values: [[ 0.00121229  0.03202801]]
# Updates: [[-0.03066097 -0.20705649]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 4.35535502  6.382478  ]
# Beta values: [[ 0.11831409  0.12809929]
#  [ 0.05813618  0.08948098]]
# Updates: [[-0.05828946 -0.12503577]
#  [-0.03669256  0.09223176]]
#
# Parsing this file: betas/betas_11_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 12.45004892]
# Beta values: [[ 1.04322851  0.02962652  0.15957237]]
# Updates: [[-0.30478739  0.18407397 -0.43856436]]
#
# Parsing this file: betas/betas_11_B_BETA_table_human_correction_human_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 7.85896301]
# Beta values: [[ 0.00099387  0.61264702]]
# Updates: [[-0.01061428 -0.40604097]]
#
# Parsing this file: betas/betas_3_B_BETA_coffee_human_correction_table_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 9.97374606]
# Beta values: [[  1.05057093e-01   4.83395231e-06]]
# Updates: [[ 0.2738148  -0.00239397]]
#
# Parsing this file: betas/betas_8_B_BETA_coffee_human_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 7.96188283]
# Beta values: [[ 0.01090666  1.89779219]]
# Updates: [[-0.15521387 -1.17941682]]
#
# Parsing this file: betas/betas_8_B_BETA_table_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.21151018]
# Beta values: [[ 0.00321532]]
# Updates: [[ 0.08948466]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 2.69385004  3.32759213  3.95694518  4.64284205]
# Beta values: [[ 0.53982387]
#  [ 2.83910369]
#  [ 0.91714817]
#  [ 0.01317743]]
# Updates: [[-0.17288913]
#  [-0.84361096]
#  [-0.68056631]
#  [ 0.0549059 ]]
#
# Parsing this file: betas/betas_8_B_BETA_table_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 2.97445011  3.64041209]
# Beta values: [[ 0.0016071 ]
#  [ 0.00019552]]
# Updates: [[-0.02901405]
#  [-0.01524008]]
#
# Parsing this file: betas/betas_4_B_BETA_table_correction_table_1.p
# Name of human: Hong
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 5.51088905  6.18701005  6.875036    7.71092606]
# Beta values: [[ 0.30016503]
#  [ 0.90651294]
#  [ 0.7393286 ]
#  [ 0.18686862]]
# Updates: [[-0.1399272 ]
#  [-0.25757876]
#  [-0.22389788]
#  [-0.17542189]]
#
# Parsing this file: betas/betas_2_B_BETA_table_human_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 4.61261106]
# Beta values: [[ 0.03310702  0.00754712]]
# Updates: [[-0.02881573  0.03681731]]
#
# Parsing this file: betas/betas_1_B_BETA_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 11.21613884]
# Beta values: [[ 0.38037038]]
# Updates: [[-0.23480318]]
#
# Parsing this file: betas/betas_4_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 4.79567599  6.10879183  7.403476  ]
# Beta values: [[ 0.06996534  0.36313514]
#  [ 0.12862716  2.11136698]
#  [ 0.17452302  0.24538466]]
# Updates: [[ 0.07692608 -0.28420472]
#  [ 0.06066494 -0.2901411 ]
#  [-0.07178131 -0.1518315 ]]
#
# Parsing this file: betas/betas_6_B_BETA_table_human_correction_coffee_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 6.13255906]
# Beta values: [[ 0.05530509  0.07293204]]
# Updates: [[-0.03272032  0.09134223]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_human_correction_coffee_2.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 6.40370798]
# Beta values: [[ 0.3409526   0.11599435  0.84331757]]
# Updates: [[ 0.12111867 -0.17907664  0.38121327]]
#
# Parsing this file: betas/betas_9_B_BETA_table_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 5.71461987  6.39959502]
# Beta values: [[ 1.09228768]
#  [ 7.90473035]]
# Updates: [[-0.32543727]
#  [-0.24285003]]
#
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 4.89826584]
# Beta values: [[ 0.00956759  0.51689481]]
# Updates: [[-0.02502155 -0.3140008 ]]
#
# Parsing this file: betas/betas_5_B_BETA_table_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.65926886  4.32385492  5.04012585]
# Beta values: [[ 0.07326914]
#  [ 0.00299419]
#  [ 0.00234854]]
# Updates: [[-0.19217545]
#  [-0.13965724]
#  [-0.01012435]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 6.5389092]
# Beta values: [[ 0.00408733  0.51400389]]
# Updates: [[ 0.05660246 -0.54677858]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 5.49927187]
# Beta values: [[ 21.79807559   0.04796284]]
# Updates: [[ 0.46893823 -0.30209034]]
#
# Parsing this file: betas/betas_5_B_BETA_table_human_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 6.10233808]
# Beta values: [[ 0.11139466  0.13665966]]
# Updates: [[ 0.20139336 -0.56607708]]
#
# Parsing this file: betas/betas_6_B_BETA_human_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 7.90090895]
# Beta values: [[ 2.36151192]]
# Updates: [[-1.23180412]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 6.44370794]
# Beta values: [[ 1.88992051  0.03360689]]
# Updates: [[-0.32773312  0.19312553]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_table_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 5.13278389  6.13062286]
# Beta values: [[ 0.09384413]
#  [ 0.01716567]]
# Updates: [[ 0.17569957]
#  [ 0.10098377]]
#
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 17.77858305]
# Beta values: [[ 0.0130173   0.00917095  2.05345776]]
# Updates: [[-0.06245304 -0.09661978 -0.83141401]]
#
# Parsing this file: betas/betas_5_B_BETA_table_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 2.97952199  3.63987899  4.44158101  5.14823508]
# Beta values: [[ 0.11382347]
#  [ 0.04603248]
#  [ 0.00484301]
#  [ 0.11027441]]
# Updates: [[-0.05749421]
#  [ 0.18815208]
#  [-0.0950627 ]
#  [-0.06043515]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.86440492]
# Beta values: [[ 0.00283441  0.00478036]]
# Updates: [[ 0.01926882 -0.04989254]]
#
# Parsing this file: betas/betas_3_B_BETA_table_correction_coffee_1.p
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 4.54915309  5.22946501]
# Beta values: [[ 0.01789008]
#  [ 0.08358689]]
# Updates: [[ 0.027644  ]
#  [ 0.09426507]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.5102129   5.01025701]
# Beta values: [[ 0.03308421  0.45447807]
#  [ 0.23002785  0.03761665]]
# Updates: [[-0.02876013 -0.17228468]
#  [ 0.21308652 -0.20668132]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [  8.04091001   9.03660893  10.07858896]
# Beta values: [[ 0.01131488]
#  [ 0.01424688]
#  [ 0.01539759]]
# Updates: [[ 0.08223171]
#  [ 0.12636006]
#  [ 0.07650496]]
#
# Parsing this file: betas/betas_9_B_BETA_table_correction_accident_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 2.57501292  3.24969387]
# Beta values: [[ 0.57714105]
#  [ 0.07845336]]
# Updates: [[ 0.48034507]
#  [ 0.15110684]]
#
# Parsing this file: betas/betas_1_B_BETA_table_coffee_correction_table_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [  9.15174985  10.73673582]
# Beta values: [[ 2.4173015   0.0865074 ]
#  [ 0.5737047   0.02538003]]
# Updates: [[-0.24562917  0.19031574]
#  [-0.16814646  0.09682445]]
#
# Parsing this file: betas/betas_8_B_BETA_table_correction_coffee_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 3.2080009   3.87554097  4.53970289  5.18791699]
# Beta values: [[ 0.62941505]
#  [ 0.80096977]
#  [ 0.4639498 ]
#  [ 1.31006899]]
# Updates: [[ 0.13338685]
#  [ 0.20721186]
#  [ 0.22178703]
#  [ 0.23451876]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 10.99841785]
# Beta values: [[ 1.12267842  0.0980976   0.03060324]]
# Updates: [[-0.29569822  0.28776076  0.21329026]]
#
# Parsing this file: betas/betas_8_B_BETA_human_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [  5.791646   10.7582531]
# Beta values: [[  1.60914610e+00]
#  [  6.19507986e-09]]
# Updates: [[-0.85781188]
#  [-0.03441555]]
#
# Parsing this file: betas/betas_4_B_BETA_human_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 6.56082082]
# Beta values: [[ 0.82982608]]
# Updates: [[-0.57751151]]
#
# Parsing this file: betas/betas_7_B_BETA_table_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 2.43926787]
# Beta values: [[ 0.01271538]]
# Updates: [[ 0.03265538]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.05233788]
# Beta values: [[ 0.00247595  0.02294269]]
# Updates: [[ 0.07986916 -0.46664578]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.00112915  4.409729    5.68618298]
# Beta values: [[ 0.20506029  0.65919905]
#  [ 0.06866945  0.02259351]
#  [ 0.16354007  0.1745467 ]]
# Updates: [[ 0.06972988 -0.17322517]
#  [-0.06330244 -0.07328644]
#  [-0.07547217 -0.16377638]]
#
# Parsing this file: betas/betas_0_B_BETA_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [  8.12556005  12.430269  ]
# Beta values: [[ 2.60213422]
#  [ 2.33370445]]
# Updates: [[ 0.69697412]
#  [ 0.98735664]]
#
# Parsing this file: betas/betas_5_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 12.7094481]
# Beta values: [[ 0.02812022  0.1192604 ]]
# Updates: [[-0.23117331 -0.53099065]]
#
# Parsing this file: betas/betas_7_B_BETA_human_correction_coffee_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 8.07727599]
# Beta values: [[ 0.07200012]]
# Updates: [[ 0.08821682]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.11496615  6.14362812]
# Beta values: [[ 0.01231421  0.00330326]
#  [ 0.00209996  0.00119381]]
# Updates: [[-0.02607535 -0.02836631]
#  [-0.01849677  0.02799217]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 4.23987794  4.84337711  5.46587014  6.08586192  6.68076992]
# Beta values: [[ 0.28921093]
#  [ 5.1080814 ]
#  [ 4.18863822]
#  [ 0.77247214]
#  [ 0.40375238]]
# Updates: [[-0.18423835]
#  [-0.37085413]
#  [-0.30615229]
#  [-0.2342337 ]
#  [-0.19851643]]
#
# Parsing this file: betas/betas_7_B_BETA_table_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 6.91537595]
# Beta values: [[  6.00593512e-04   4.94255065e+00]]
# Updates: [[-0.02307377 -1.53379707]]
#
# Parsing this file: betas/betas_4_B_BETA_coffee_human_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 9.09639502]
# Beta values: [[ 0.00427174  0.67292556]]
# Updates: [[-0.05349769 -0.55025851]]
#
# Parsing this file: betas/betas_7_B_BETA_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 6.57056499]
# Beta values: [[ 4.94995176]]
# Updates: [[-1.53379707]]
#
# Parsing this file: betas/betas_11_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 4.23553109]
# Beta values: [[ 0.00586123  1.15379034]]
# Updates: [[ 0.01741333 -0.28012934]]
#
# Parsing this file: betas/betas_6_B_BETA_table_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 7.70412207  8.36614394  9.02233696  9.72377205]
# Beta values: [[ 0.32254349]
#  [ 0.28252676]
#  [ 0.59016674]
#  [ 0.13623812]]
# Updates: [[-0.17728951]
#  [-0.20974616]
#  [-0.2725731 ]
#  [-0.10319681]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 11.88504601]
# Beta values: [[ 0.0074629  0.       ]]
# Updates: [[-0.09661978 -0.83141401]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 12.5428021]
# Beta values: [[ 0.00112282  0.        ]]
# Updates: [[-0.0289123   0.68299719]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 6.27284288]
# Beta values: [[ 0.34265518  0.00935428]]
# Updates: [[-0.23625293  0.09544321]]
#
# Parsing this file: betas/betas_3_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 5.2216382]
# Beta values: [[ 0.01997213  1.48313156]]
# Updates: [[ 0.02719001 -0.25117555]]
#
# Parsing this file: betas/betas_11_B_BETA_coffee_human_correction_table_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 10.49706411]
# Beta values: [[ 0.0849885   0.00394771]]
# Updates: [[ 0.35455035  0.0980833 ]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 14.36550403]
# Beta values: [[ 0.01229829  0.00368767  0.58426809]]
# Updates: [[-0.02607535 -0.02836631 -0.2949893 ]]
#
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 8.238451]
# Beta values: [[ 0.16752966  0.25979918]]
# Updates: [[ 0.06948522  0.1899676 ]]
#
# Parsing this file: betas/betas_9_B_BETA_human_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 4.20352006]
# Beta values: [[ 1.37712068]]
# Updates: [[-0.72279712]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 15.66638088]
# Beta values: [[  2.12291331e-03   9.83937264e-03   2.96764761e+00]]
# Updates: [[-0.03337413 -0.15521387 -1.17941682]]
#
# Parsing this file: betas/betas_5_B_BETA_human_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 11.25964093]
# Beta values: [[ 0.66354337]]
# Updates: [[-0.65661677]]
#
# Parsing this file: betas/betas_11_B_BETA_table_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 3.59900808  4.24850512]
# Beta values: [[ 0.0066001 ]
#  [ 0.01022674]]
# Updates: [[ 0.01882468]
#  [-0.06654824]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 2.73651099]
# Beta values: [[ 0.01802615]]
# Updates: [[-0.07606484]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 13.61583805]
# Beta values: [[  8.25813392e-02   9.22763914e-04   3.23697966e+00]]
# Updates: [[-0.19714417 -0.04805459 -1.20384052]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 5.13953805  9.97576499]
# Beta values: [[ 0.00106148]
#  [ 0.04363003]]
# Updates: [[-0.0289123 ]
#  [ 0.18217064]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.95208001]
# Beta values: [[ 0.00805163]]
# Updates: [[-0.09661978]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.32814312]
# Beta values: [[ 0.00528057  0.02142578]]
# Updates: [[ 0.03402593 -0.14165144]]
#
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [  7.95195103  16.95473981]
# Beta values: [[  1.86849496e-01   1.27940234e-03   1.97202145e+00]
#  [  2.04696032e-03   2.65542017e-02   6.67628372e-01]]
# Updates: [[ 0.15804485 -0.0289123   0.68299719]
#  [-0.02555654  0.19403331  0.9878667 ]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 3.69824004  5.0824492 ]
# Beta values: [[  1.03231109e+00   1.12607975e-01]
#  [  1.56973620e-01   2.67601948e-05]]
# Updates: [[-0.29569822  0.28776076]
#  [-0.19544136  0.00599685]]
#
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 14.23755002]
# Beta values: [[ 0.89849666  0.09342132  0.        ]]
# Updates: [[-0.1793054   0.17569957  0.10679792]]
#
# Parsing this file: betas/betas_11_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 10.16688704]
# Beta values: [[ 0.00580096  1.2431154   0.        ]]
# Updates: [[ 0.01741333 -0.28012934 -0.14482644]]
#
# Parsing this file: betas/betas_5_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 11.38572192]
# Beta values: [[ 0.12902249  0.46030929]]
# Updates: [[-0.12503577 -0.23947359]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_accident_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.58727503  5.2572701   5.98056507  7.04615211  7.9509232 ]
# Beta values: [[ 0.22412507]
#  [ 0.03719831]
#  [ 0.01615582]
#  [ 0.08706367]
#  [ 0.02072352]]
# Updates: [[-0.20410638]
#  [-0.37636018]
#  [-0.1404186 ]
#  [ 0.32729816]
#  [ 0.08987239]]
#
# Parsing this file: betas/betas_6_B_BETA_human_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 15.28808689]
# Beta values: [[ 1.00931026]]
# Updates: [[-0.48428202]]
#
# Parsing this file: betas/betas_11_B_BETA_table_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.75199008]
# Beta values: [[ 0.8995272   0.16736991]]
# Updates: [[-0.30346572 -0.46883259]]
#
# Parsing this file: betas/betas_9_B_BETA_table_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 2.97778392  3.64019799  4.34102392]
# Beta values: [[ 0.00656923]
#  [ 0.00525125]
#  [ 0.00871116]]
# Updates: [[ 0.03695454]
#  [ 0.10904398]
#  [ 0.01627617]]
#
# Parsing this file: betas/betas_4_B_BETA_coffee_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.82252312  4.43909311  5.04638195  5.66480398  6.27103996  6.88247609]
# Beta values: [[ 0.53588777]
#  [ 2.35324308]
#  [ 2.8391478 ]
#  [ 3.14068315]
#  [ 1.71423977]
#  [ 0.08235117]]
# Updates: [[-0.28420472]
#  [-0.30743973]
#  [-0.27578669]
#  [-0.25959443]
#  [-0.19463709]
#  [-0.12081858]]
#
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_table_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 4.56903601]
# Beta values: [[ 0.71344143  0.16023566]]
# Updates: [[-0.21059087 -0.33710002]]
#
# Parsing this file: betas/betas_5_B_BETA_table_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 4.87937284  5.600595    6.26461887]
# Beta values: [[ 0.38855787]
#  [ 0.21180252]
#  [ 2.03257722]]
# Updates: [[-0.23242398]
#  [-0.80467106]
#  [ 0.35343772]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 9.83605909]
# Beta values: [[ 0.01802437  0.51787908]]
# Updates: [[-0.07606484 -0.36126237]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_correction_accident_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.18040705  4.88212705  5.57953095]
# Beta values: [[ 0.04871553]
#  [ 0.03433693]
#  [ 0.02566303]]
# Updates: [[-0.30209034]
#  [-0.45930606]
#  [-0.09163078]]
#
# Parsing this file: betas/betas_3_B_BETA_coffee_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.57986093]
# Beta values: [[ 0.00875912]]
# Updates: [[-0.21903556]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 16.81184602]
# Beta values: [[ 0.03257315  1.15533849]]
# Updates: [[-0.83790302 -3.68466388]]
#
# Parsing this file: betas/betas_3_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 7.66919112]
# Beta values: [[  9.47201224e-03   9.50345125e+00]]
# Updates: [[-0.22654306 -1.94499804]]
#
# Parsing this file: betas/betas_3_B_BETA_table_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.18567991]
# Beta values: [[ 0.00102173]]
# Updates: [[-0.03559949]]
# Parsing this file: betas/betas_9_B_BETA_table_human_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 11.13614893]
# Beta values: [[ 0.33461889  1.62920841]]
# Updates: [[ 0.12037325  0.39062223]]
#
# Parsing this file: betas/betas_8_B_BETA_table_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 4.58321285  5.25314188  5.91603804  6.60773587  7.25625706  7.92198801]
# Beta values: [[ 0.01528994]
#  [ 0.30579846]
#  [ 0.90036708]
#  [ 0.32423222]
#  [ 0.46119263]
#  [ 0.89103709]]
# Updates: [[-0.06596263]
#  [-0.17734727]
#  [-0.2733325 ]
#  [-0.1796483 ]
#  [-0.31027872]
#  [-0.18803454]]
#
# Parsing this file: betas/betas_0_B_BETA_human_correction_coffee_1.p
# Name of human: Andreea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 12.29804277]
# Beta values: [[ 0.54686035]]
# Updates: [[-0.26861033]]
#
# Parsing this file: betas/betas_5_B_BETA_coffee_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.56515408]
# Beta values: [[ 0.02792576]]
# Updates: [[-0.22519768]]
#
# Parsing this file: betas/betas_4_B_BETA_table_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.47302103  4.14993095  4.82238007  5.51727891  6.18146396]
# Beta values: [[ 0.00040736]
#  [ 0.08558632]
#  [ 0.07745901]
#  [ 0.00081941]
#  [ 0.00537449]]
# Updates: [[-0.00800762]
#  [ 0.10633427]
#  [ 0.10735739]
#  [-0.01345297]
#  [-0.02373705]]
#
# Parsing this file: betas/betas_4_B_BETA_table_correction_accident_1.p
# Name of human: Hong
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.84271288  4.52057099  5.25795984]
# Beta values: [[  3.15170351]
#  [ 18.42300881]
#  [  1.46950553]]
# Updates: [[ 0.55788998]
#  [ 0.63331541]
#  [ 0.32951735]]
#
# Parsing this file: betas/betas_11_B_BETA_table_human_correction_table_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 9.00841904]
# Beta values: [[  2.37415284e+00   2.33176248e-03]]
# Updates: [[-0.40884959  0.07429204]]
#
# Parsing this file: betas/betas_3_B_BETA_coffee_human_correction_human_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 10.09000015]
# Beta values: [[  5.14718620e-04   9.26645821e-01]]
# Updates: [[-0.0213528  -0.66874074]]
#
# Parsing this file: betas/betas_4_B_BETA_coffee_correction_accident_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.84233594  4.54143286  5.33466196]
# Beta values: [[ 0.04846381]
#  [ 0.0439563 ]
#  [ 0.03016737]]
# Updates: [[-0.36255118]
#  [-0.42581884]
#  [-0.21331337]]
#
# Parsing this file: betas/betas_8_B_BETA_coffee_human_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 12.60831904]
# Beta values: [[ 0.00265478  1.51302883]]
# Updates: [[-0.05923407 -0.83363245]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.13110089]
# Beta values: [[ 0.01289593]]
# Updates: [[-0.20705649]]
#
# Parsing this file: betas/betas_11_B_BETA_table_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 2.99730992]
# Beta values: [[ 0.60228972]]
# Updates: [[-0.30346572]]
#
# Parsing this file: betas/betas_1_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 14.71530318]
# Beta values: [[ 0.48960036  0.06892324  0.04905539]]
# Updates: [[ 0.20238998 -0.20410638 -0.20303925]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Parsing this file: betas/betas_4_B_BETA_table_human_correction_accident_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 13.13222694]
# Beta values: [[ 2.69495046  0.1640746 ]]
# Updates: [[ 0.55788998  0.74320805]]
#
# Parsing this file: betas/betas_7_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 12.71043086]
# Beta values: [[ 0.01151224  0.0177716   0.57890591]]
# Updates: [[ 0.03142472 -0.07606484 -0.36126237]]
#
# Parsing this file: betas/betas_4_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 11.29675508]
# Beta values: [[ 0.36697111  0.18472519]]
# Updates: [[-0.28420472 -0.28420291]]
#
# Parsing this file: betas/betas_7_B_BETA_human_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 5.85322881]
# Beta values: [[ 0.62456715]]
# Updates: [[-0.38067076]]
#
# Parsing this file: betas/betas_6_B_BETA_table_coffee_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [  8.99128914  11.03101015]
# Beta values: [[ 0.35012256  0.01185933]
#  [ 0.18655431  0.01693739]]
# Updates: [[-0.18157773  0.08486993]
#  [-0.11636312  0.07884903]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [  3.99050999   4.73282313  10.43998313  11.05493808  11.7483151
#   14.84620309]
# Beta values: [[ 0.02927065]
#  [ 0.04818447]
#  [ 0.70201459]
#  [ 0.48321365]
#  [ 0.57118966]
#  [ 0.05370745]]
# Updates: [[-0.83790302]
#  [ 0.11439754]
#  [-0.23568787]
#  [-0.40014097]
#  [-0.36059085]
#  [ 0.12431853]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_table_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [  8.13764215   9.15134001  10.22556305]
# Beta values: [[ 0.07260384]
#  [ 0.06374848]
#  [ 0.02035852]]
# Updates: [[ 0.19031574]
#  [ 0.20830469]
#  [ 0.09073149]]
#
# Parsing this file: betas/betas_4_B_BETA_table_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 3.94269395  4.6246779   5.29513383  5.97205901  6.63574386]
# Beta values: [[ 0.07134003]
#  [ 0.09840185]
#  [ 0.04411661]
#  [ 0.12340914]
#  [ 0.00624177]]
# Updates: [[ 0.07916075]
#  [ 0.07418724]
#  [ 0.04797152]
#  [ 0.04979608]
#  [-0.01460554]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 11.82973194]
# Beta values: [[ 0.01569431  0.00298058  1.19003129]]
# Updates: [[-0.07043449 -0.05748511 -0.8279992 ]]
#
# Parsing this file: betas/betas_9_B_BETA_human_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 15.1611259]
# Beta values: [[ 0.04111141]]
# Updates: [[-0.47116784]]
#
# Parsing this file: betas/betas_10_B_BETA_coffee_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 2.39080191  3.20281601  3.9764781   4.69186091  5.45645094]
# Beta values: [[ 0.39625531]
#  [ 0.24474292]
#  [ 0.01374968]
#  [ 0.04563562]
#  [ 0.18695046]]
# Updates: [[-0.17322517]
#  [-0.18964963]
#  [-0.06560205]
#  [-0.10522247]
#  [-0.15334446]]
#
# Parsing this file: betas/betas_5_B_BETA_human_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 13.51232481]
# Beta values: [[ 1.44793338]]
# Updates: [[-1.24179612]]
#
# Parsing this file: betas/betas_2_B_BETA_table_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 2.72237206  3.42531204  4.11844206  4.82540798]
# Beta values: [[ 0.03091674]
#  [ 0.0411468 ]
#  [ 0.13051382]
#  [ 0.00037744]]
# Updates: [[-0.02878934]
#  [ 0.15159328]
#  [ 0.20880609]
#  [-0.00663979]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 3.04458189  4.09390283  5.11191893]
# Beta values: [[ 0.0038933 ]
#  [ 0.018394  ]
#  [ 0.01355538]]
# Updates: [[ 0.05660246]
#  [ 0.08331508]
#  [ 0.09973248]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 11.73226905]
# Beta values: [[ 0.2136065   0.00777687  0.44790487]]
# Updates: [[-0.23625293  0.09544321 -0.62237766]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.96930599]
# Beta values: [[ 0.08393075  0.0009749 ]]
# Updates: [[-0.19714417 -0.04805459]]
#
# Parsing this file: betas/betas_11_B_BETA_coffee_human_correction_human_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 9.25005603]
# Beta values: [[ 0.00199182  0.        ]]
# Updates: [[-0.02839056 -0.3829252 ]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 6.1486001]
# Beta values: [[ 0.73028273  0.01979118  0.13441464]]
# Updates: [[-0.21176057  0.10613204 -0.31244882]]
#
# Parsing this file: betas/betas_9_B_BETA_table_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 3.00979495  3.69437885]
# Beta values: [[ 0.27415147]
#  [ 0.15759709]]
# Updates: [[ 0.12037325]
#  [ 0.12603284]]
#
# Parsing this file: betas/betas_10_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 9.74556112]
# Beta values: [[ 0.4000191  0.       ]]
# Updates: [[-0.17322517  0.18735416]]
#
# Parsing this file: betas/betas_3_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 14.27280617]
# Beta values: [[ 0.00177672  0.01334454  0.90109352]]
# Updates: [[-0.04610572 -0.22654306 -1.94499804]]
#
# Parsing this file: betas/betas_1_B_BETA_table_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 6.9084239]
# Beta values: [[ 0.00456665  0.33550611]]
# Updates: [[-0.01433278 -0.23480318]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 9.77319002]
# Beta values: [[ 0.2276523   0.4053731   0.25595166]]
# Updates: [[ 0.06972988 -0.17322517  0.18735416]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_correction_coffee_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 2.57751679  3.18252087  3.78035378  4.38146496]
# Beta values: [[ 0.7708547 ]
#  [ 0.60304361]
#  [ 5.9303983 ]
#  [ 6.17920274]]
# Updates: [[-0.15903544]
#  [-0.31067856]
#  [-0.3836019 ]
#  [-0.46799906]]
#
# Parsing this file: betas/betas_4_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 5.14538407]
# Beta values: [[ 3.98962452  0.07342787]]
# Updates: [[ 0.55949165 -0.36255118]]
#
# Parsing this file: betas/betas_6_B_BETA_table_human_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [  7.19643688  11.22560501  15.53446984]
# Beta values: [[ 0.03510479  1.37894884]
#  [ 2.07929903  0.        ]
#  [ 0.00772263  0.        ]]
# Updates: [[ 0.43122677 -3.658369  ]
#  [ 0.21677947  0.        ]
#  [-0.02445846  0.        ]]
#
# Parsing this file: betas/betas_6_B_BETA_table_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.10909796  3.80796289  4.47496986]
# Beta values: [[ 0.04464599]
#  [ 0.00151515]
#  [ 0.0631553 ]]
# Updates: [[-0.15290323]
#  [-0.09730846]
#  [ 0.06674016]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Eli
# ...
# Was human rational? False
# Timestamp of pushes: [ 17.52595186]
# Beta values: [[ 0.06574849  0.02288027]]
# Updates: [[ 0.19031574 -0.13671562]]
#
# Parsing this file: betas/betas_8_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 7.33213711]
# Beta values: [[ 0.02013436  1.67774146]]
# Updates: [[-0.45383775 -2.47436901]]
#
# Parsing this file: betas/betas_8_B_BETA_coffee_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 3.254246]
# Beta values: [[ 0.02184085]]
# Updates: [[-0.46664578]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.87155294]
# Beta values: [[ 0.34421636  0.11372863]]
# Updates: [[ 0.12111867 -0.17907664]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 12.65088582]
# Beta values: [[ 0.17689606  0.07623805]]
# Updates: [[-0.10456085  0.09307249]]
#
# Parsing this file: betas/betas_8_B_BETA_coffee_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 4.9518559   5.94406486  6.93100691  7.92280197]
# Beta values: [[ 0.00270385]
#  [ 0.1173006 ]
#  [ 0.04578018]
#  [ 0.04956499]]
# Updates: [[-0.05748511]
#  [ 0.24201898]
#  [ 0.17316442]
#  [ 0.2445241 ]]
#
# Parsing this file: betas/betas_1_B_BETA_table_correction_human_1.p
# Name of human: Andrea
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.69358897  4.38036394  5.03530884  5.71021485]
# Beta values: [[  3.63730795e-02]
#  [  7.35373062e-04]
#  [  2.04468787e-02]
#  [  4.73767837e-05]]
# Updates: [[ 0.08367254]
#  [-0.02607645]
#  [-0.09557587]
#  [ 0.00130027]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 4.01468611]
# Beta values: [[ 0.10476481  0.02643469]]
# Updates: [[ 0.19647934 -0.22519768]]
# Parsing this file: betas/betas_4_B_BETA_human_correction_accident_1.p
# Name of human: Hong
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 5.73125291]
# Beta values: [[ 0.15932266]]
# Updates: [[ 0.74320805]]
#
# Parsing this file: betas/betas_11_B_BETA_human_correction_table_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 10.68132782]
# Beta values: [[ 0.00254745]]
# Updates: [[ 0.07429204]]
#
# Parsing this file: betas/betas_8_B_BETA_table_human_correction_coffee_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 9.37744808]
# Beta values: [[ 0.69298026  0.2543321 ]]
# Updates: [[ 0.13433443  0.25378227]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 13.72817492]
# Beta values: [[ 0.05117445  0.02944775]]
# Updates: [[-0.30209034  0.29129599]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 12.04458284]
# Beta values: [[ 0.00264851  0.02946263  2.02249291]]
# Updates: [[ 0.07986916 -0.46664578 -2.50466905]]
#
# Parsing this file: betas/betas_3_B_BETA_table_correction_human_1.p
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 2.91538     3.58721185  4.24401093]
# Beta values: [[ 0.04233145]
#  [ 0.00025613]
#  [ 0.00988406]]
# Updates: [[-0.0943054 ]
#  [ 0.0090624 ]
#  [ 0.02679099]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_correction_coffee_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 4.75472999  5.36621499  5.97515082]
# Beta values: [[ 0.17692591]
#  [ 4.51580093]
#  [ 1.38302222]]
# Updates: [[-0.10456085]
#  [-0.44563311]
#  [-0.4925748 ]]
#
# Parsing this file: betas/betas_9_B_BETA_coffee_human_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 14.22966909]
# Beta values: [[ 0.03377355  0.14774671]]
# Updates: [[ 0.19312553 -0.45324319]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_human_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 11.301548]
# Beta values: [[ 0.00568473  0.        ]]
# Updates: [[-0.04989254 -0.41922024]]
#
# Parsing this file: betas/betas_3_B_BETA_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 9.5339911]
# Beta values: [[ 0.]]
# Updates: [[-1.96454967]]
#
# Parsing this file: betas/betas_0_B_BETA_table_correction_coffee_1.p
# Name of human: Andreea
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 4.30439401  4.98304081  5.68706989]
# Beta values: [[ 0.09317148]
#  [ 0.0125649 ]
#  [ 0.00857214]]
# Updates: [[-0.07124415]
#  [-0.05290162]
#  [ 0.03495797]]
#
# Parsing this file: betas/betas_5_B_BETA_coffee_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 5.23480415  6.23839903]
# Beta values: [[ 0.00873864]
#  [ 0.09132574]]
# Updates: [[ 0.09544321]
#  [ 0.80289033]]
#
# Parsing this file: betas/betas_5_B_BETA_table_human_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 12.63113284]
# Beta values: [[ 0.38264554  0.61148834]]
# Updates: [[-0.23242398 -0.65661677]]
#
# Parsing this file: betas/betas_4_B_BETA_human_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human rational? False
# Timestamp of pushes: [ 8.01583004]
# Beta values: [[ 0.21068474]]
# Updates: [[-0.29577947]]
#
# Parsing this file: betas/betas_0_B_BETA_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 8.38832712]
# Beta values: [[ 2.08240225]]
# Updates: [[-0.86202889]]
#
# Parsing this file: betas/betas_11_B_BETA_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 10.83191085]
# Beta values: [[ 0.19313261]]
# Updates: [[-0.46883259]]
#
# Parsing this file: betas/betas_6_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 15.33631706]
# Beta values: [[ 0.43271442  0.01006264  1.92510036]]
# Updates: [[-0.18111442  0.08223171 -0.47804828]]
#
# Parsing this file: betas/betas_11_B_BETA_coffee_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.54202008  4.16383004]
# Beta values: [[ 1.16220657]
#  [ 0.83325187]]
# Updates: [[-0.28012934]
#  [-0.78355388]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 11.78642797]
# Beta values: [[ 0.15507394  0.        ]]
# Updates: [[-0.17278251 -0.25581318]]
#
# Parsing this file: betas/betas_7_B_BETA_table_coffee_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 4.00402904  6.00464797]
# Beta values: [[ 0.27837997  0.00378558]
#  [ 0.30446997  0.01484705]]
# Updates: [[-0.1781826   0.05660246]
#  [-0.18345519  0.09917094]]
#
# Parsing this file: betas/betas_2_B_BETA_table_human_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 9.33224607]
# Beta values: [[ 0.00322359  0.50435576]]
# Updates: [[ 0.02037566 -0.44491134]]
#
# Parsing this file: betas/betas_3_B_BETA_table_human_correction_human_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 9.95697904]
# Beta values: [[ 0.04713074  1.17329153]]
# Updates: [[-0.0943054  -0.70097274]]
#
# Parsing this file: betas/betas_3_B_BETA_table_coffee_correction_table_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 7.08529282]
# Beta values: [[ 3.083713    0.12503708]]
# Updates: [[-0.28470933  0.27925361]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 4.341079]
# Beta values: [[ 0.00188991  0.01012661]]
# Updates: [[-0.03337413 -0.15521387]]
#
# Parsing this file: betas/betas_3_B_BETA_table_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 8.72467303]
# Beta values: [[  9.31328684e-04   1.04719805e+01]]
# Updates: [[-0.03611006 -1.96454967]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 9.60011506]
# Beta values: [[ 0.11841538  0.11706825  0.45761795]]
# Updates: [[-0.05828946 -0.12503577 -0.23947359]]
#
# Parsing this file: betas/betas_4_B_BETA_table_human_correction_table_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 17.58365989]
# Beta values: [[ 0.26386715  1.08553542]]
# Updates: [[-0.1399272  -0.42218341]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 11.12446809]
# Beta values: [[ 0.32108664  0.30121852]]
# Updates: [[-0.18513826 -0.22497674]]
#
# Parsing this file: betas/betas_1_B_BETA_human_correction_table_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human rational? False
# Timestamp of pushes: [ 10.60111785]
# Beta values: [[ 0.03815203]]
# Updates: [[-0.16582122]]
#
# Parsing this file: betas/betas_1_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 12.89605403]
# Beta values: [[ 0.03393653  0.0308269   0.        ]]
# Updates: [[ 0.08114473 -0.16043026 -0.60229369]]
#
# Parsing this file: betas/betas_2_B_BETA_table_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human rational? True
# Timestamp of pushes: [ 2.93647504  3.65576792  4.32034588]
# Beta values: [[ 0.67683829]
#  [ 7.98485511]
#  [ 0.11221263]]
# Updates: [[-0.29713026]
#  [-0.67536544]
#  [-0.16946112]]
#
# Parsing this file: betas/betas_4_B_BETA_coffee_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human rational? False
# Timestamp of pushes: [ 3.86409283  4.88783002  5.91223598]
# Beta values: [[ 0.00426884]
#  [ 0.01611246]
#  [ 0.00253636]]
# Updates: [[-0.05349769]
#  [-0.06294611]
#  [-0.04375976]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_human_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 14.24873996]
# Beta values: [[  9.97917313e-04   6.15698493e+00]]
# Updates: [[-0.04953888 -1.18864824]]
#
# Parsing this file: betas/betas_10_B_BETA_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human rational? True
# Timestamp of pushes: [ 8.466048]
# Beta values: [[ 0.]]
# Updates: [[-0.3140008]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 13.08458686]
# Beta values: [[ 0.55263288  0.07480218  0.06595864]]
# Updates: [[ 0.47821798 -0.51083758 -0.58363039]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human rational? False
# Timestamp of pushes: [ 11.85938287]
# Beta values: [[ 0.01320401  0.        ]]
# Updates: [[-0.20705649 -1.50331708]]
#
# Parsing this file: betas/betas_9_B_BETA_coffee_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 3.14046884  3.78904295]
# Beta values: [[ 0.33885719]
#  [ 0.4935131 ]]
# Updates: [[-0.17907664]
#  [-0.35935325]]
#
# Parsing this file: betas/betas_1_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human rational? True
# Timestamp of pushes: [ 12.94194603]
# Beta values: [[ 0.00641182  0.39824949  0.        ]]
# Updates: [[-0.01608912 -0.18423835 -0.22175409]]

# %%
import numpy as np
import glob
import pickle 
import csv
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab

from scipy import stats  

person_names = {0: "Andreea", 1: "Andrea", 2: "Eli", 3: "Ravi", 4: "Hong", 5: "Ellis", 6: "Steven", 7:"Smitha", 8:"Simon", 9:"Erin", 10:"Mitch", 11:"Elizabeth"}
corrections_str = []
for file in glob.glob('betas/*_BETA_*.p'):
    corrections_str.append(file)
    
csv_table = [["Name", "R_feat", "H_feat", "Correction #", "Timestamp", "Update", "Intentional", "Beta"]]
    
for file_path in corrections_str:
    # Parse string to find features known and features corrected
    print "Parsing this file:", file_path
    str_list = file_path.split("_")
    method_idx = str_list.index("BETA")
    correction_idx = str_list.index("correction")
    end_idx = len(str_list)-1
    
    person_ID = person_names[int(str_list[1])]
    features_known = str_list[method_idx+1:correction_idx]
    features_corrected = str_list[correction_idx+1:-1]
    is_rational = not set(features_known).isdisjoint(features_corrected)
    
    betas = pickle.load(open(file_path, "rb"))
    if betas is None:
        continue
    timestamp = betas[:,0]
    betas = betas[:,1:]
        
    print "Name of human:", person_ID
    print "Robot knew about these features:", features_known
    print "Human was asked to correct these features:", features_corrected  
    print "Was human intentional?", is_rational
    print "Timestamp of pushes:", timestamp
    print "Beta values:", betas
  
    # Look at update data
    update_str = "updates/updates_" + ('_').join(str_list[1:])
    updates = pickle.load(open(update_str, "rb"))
    updates = updates[:,1:]
    print "Updates:", updates, "\n"
    
    # Create csv data
    for i in range(len(timestamp)):
        for j in range(len(betas[i])):
            if abs(updates[i,j]) < 0.1 or betas[i,j] == 0:
                continue
            is_rational = features_known[j] == features_corrected[0]
            csv_row_current = [person_ID, features_known[j], features_corrected[0], i, timestamp[i], updates[i,j], is_rational, betas[i,j]]
            csv_table.append(csv_row_current)
            print(csv_row_current)
    
csv_file = open('beta_offline.csv', 'w')
with csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(csv_table)
    
df = pd.DataFrame(data=csv_table[:][1:], columns=csv_table[:][0])
# Out:
# Parsing this file: betas/betas_1_B_BETA_human_correction_accident_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.64570308  9.85766697]
# Beta values: [[ 0.04988554]
#  [ 0.20730106]]
# Updates: [[-0.21464616]
#  [ 1.08244706]]
#
# ['Andrea', 'human', 'accident', 0, 4.6457030773162842, -0.21464616234618461, False, 0.049885537315410552]
# ['Andrea', 'human', 'accident', 1, 9.8576669692993164, 1.0824470593841724, False, 0.20730106253787803]
# Parsing this file: betas/betas_7_B_BETA_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 7.84293389]
# Beta values: [[ 0.61597337]]
# Updates: [[-0.57748885]]
#
# ['Smitha', 'human', 'table', 0, 7.8429338932037354, -0.57748885192260957, False, 0.6159733685799389]
# Parsing this file: betas/betas_6_B_BETA_table_coffee_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 4.49922204]
# Beta values: [[ 0.04720027  0.00103463]]
# Updates: [[-0.15733646 -0.04953888]]
#
# ['Steven', 'table', 'human', 0, 4.4992220401763916, -0.15733646071742413, False, 0.047200268873142069]
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_human_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 4.09294295  4.76658201  5.42512703]
# Beta values: [[ 0.02788572]
#  [ 0.00686173]
#  [ 0.00982675]]
# Updates: [[-0.16043026]
#  [-0.14640746]
#  [ 0.05516381]]
#
# ['Andrea', 'coffee', 'human', 0, 4.0929429531097412, -0.1604302562924218, False, 0.027885715329391332]
# ['Andrea', 'coffee', 'human', 1, 4.7665820121765137, -0.14640746006029559, False, 0.0068617251697960435]
# Parsing this file: betas/betas_6_B_BETA_human_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [  8.01034808  10.43267798  11.04193211  11.64574313  14.83260202]
# Beta values: [[ 0.5772626]
#  [ 0.       ]
#  [ 0.       ]
#  [ 0.       ]
#  [ 0.       ]]
# Updates: [[-3.658369]
#  [ 0.      ]
#  [ 0.      ]
#  [ 0.      ]
#  [ 0.      ]]
#
# ['Steven', 'human', 'accident', 0, 8.0103480815887451, -3.6583689976839011, False, 0.57726260291475062]
# Parsing this file: betas/betas_7_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 18.11833286]
# Beta values: [[ 0.27767115  0.00398773  1.70613207]]
# Updates: [[-0.1781826   0.05660246 -0.54677858]]
#
# ['Smitha', 'table', 'table', 0, 18.118332862854004, -0.17818260393044838, True, 0.27767114903538365]
# ['Smitha', 'human', 'table', 0, 18.118332862854004, -0.54677858335109875, False, 1.7061320662390109]
# Parsing this file: betas/betas_7_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 5.15978503]
# Beta values: [[ 0.00121229  0.03202801]]
# Updates: [[-0.03066097 -0.20705649]]
#
# ['Smitha', 'coffee', 'accident', 0, 5.1597850322723389, -0.20705649467641507, False, 0.032028005542777439]
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 4.35535502  6.382478  ]
# Beta values: [[ 0.11831409  0.12809929]
#  [ 0.05813618  0.08948098]]
# Updates: [[-0.05828946 -0.12503577]
#  [-0.03669256  0.09223176]]
#
# ['Ellis', 'coffee', 'coffee', 0, 4.3553550243377686, -0.12503577496229923, True, 0.1280992882040029]
# Parsing this file: betas/betas_11_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 12.45004892]
# Beta values: [[ 1.04322851  0.02962652  0.15957237]]
# Updates: [[-0.30478739  0.18407397 -0.43856436]]
#
# ['Elizabeth', 'table', 'accident', 0, 12.450048923492432, -0.30478738693307506, False, 1.0432285068853642]
# ['Elizabeth', 'coffee', 'accident', 0, 12.450048923492432, 0.18407397454813434, False, 0.029626520671665199]
# ['Elizabeth', 'human', 'accident', 0, 12.450048923492432, -0.43856435928768178, False, 0.15957236683762049]
# Parsing this file: betas/betas_11_B_BETA_table_human_correction_human_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 7.85896301]
# Beta values: [[ 0.00099387  0.61264702]]
# Updates: [[-0.01061428 -0.40604097]]
#
# ['Elizabeth', 'human', 'human', 0, 7.8589630126953125, -0.40604096931382117, True, 0.61264702044676]
# Parsing this file: betas/betas_3_B_BETA_coffee_human_correction_table_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 9.97374606]
# Beta values: [[  1.05057093e-01   4.83395231e-06]]
# Updates: [[ 0.2738148  -0.00239397]]
#
# ['Ravi', 'coffee', 'table', 0, 9.9737460613250732, 0.27381479724530067, False, 0.1050570928088292]
# Parsing this file: betas/betas_8_B_BETA_coffee_human_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 7.96188283]
# Beta values: [[ 0.01090666  1.89779219]]
# Updates: [[-0.15521387 -1.17941682]]
#
# ['Simon', 'coffee', 'human', 0, 7.9618828296661377, -0.15521386752609345, False, 0.010906658556387675]
# ['Simon', 'human', 'human', 0, 7.9618828296661377, -1.1794168195389432, True, 1.8977921907706179]
# Parsing this file: betas/betas_8_B_BETA_table_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 3.21151018]
# Beta values: [[ 0.00321532]]
# Updates: [[ 0.08948466]]
#
# Parsing this file: betas/betas_2_B_BETA_coffee_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 2.69385004  3.32759213  3.95694518  4.64284205]
# Beta values: [[ 0.53982387]
#  [ 2.83910369]
#  [ 0.91714817]
#  [ 0.01317743]]
# Updates: [[-0.17288913]
#  [-0.84361096]
#  [-0.68056631]
#  [ 0.0549059 ]]
#
# ['Eli', 'coffee', 'coffee', 0, 2.693850040435791, -0.17288912967680403, True, 0.5398238734099442]
# ['Eli', 'coffee', 'coffee', 1, 3.327592134475708, -0.84361096328777307, True, 2.8391036929312983]
# ['Eli', 'coffee', 'coffee', 2, 3.9569451808929443, -0.68056631238512466, True, 0.91714817033420259]
# Parsing this file: betas/betas_8_B_BETA_table_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 2.97445011  3.64041209]
# Beta values: [[ 0.0016071 ]
#  [ 0.00019552]]
# Updates: [[-0.02901405]
#  [-0.01524008]]
#
# Parsing this file: betas/betas_4_B_BETA_table_correction_table_1.p
# Name of human: Hong
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 5.51088905  6.18701005  6.875036    7.71092606]
# Beta values: [[ 0.30016503]
#  [ 0.90651294]
#  [ 0.7393286 ]
#  [ 0.18686862]]
# Updates: [[-0.1399272 ]
#  [-0.25757876]
#  [-0.22389788]
#  [-0.17542189]]
#
# ['Hong', 'table', 'table', 0, 5.5108890533447266, -0.13992719867997749, True, 0.3001650320673192]
# ['Hong', 'table', 'table', 1, 6.1870100498199463, -0.25757876214284892, True, 0.90651294340388833]
# ['Hong', 'table', 'table', 2, 6.8750360012054443, -0.22389788199114591, True, 0.73932859520369665]
# ['Hong', 'table', 'table', 3, 7.7109260559082031, -0.17542189450778345, True, 0.18686861851751127]
# Parsing this file: betas/betas_2_B_BETA_table_human_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 4.61261106]
# Beta values: [[ 0.03310702  0.00754712]]
# Updates: [[-0.02881573  0.03681731]]
#
# Parsing this file: betas/betas_1_B_BETA_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 11.21613884]
# Beta values: [[ 0.38037038]]
# Updates: [[-0.23480318]]
#
# ['Andrea', 'human', 'coffee', 0, 11.21613883972168, -0.23480318382600984, False, 0.38037038234139781]
# Parsing this file: betas/betas_4_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 4.79567599  6.10879183  7.403476  ]
# Beta values: [[ 0.06996534  0.36313514]
#  [ 0.12862716  2.11136698]
#  [ 0.17452302  0.24538466]]
# Updates: [[ 0.07692608 -0.28420472]
#  [ 0.06066494 -0.2901411 ]
#  [-0.07178131 -0.1518315 ]]
#
# ['Hong', 'coffee', 'coffee', 0, 4.7956759929656982, -0.2842047222855939, True, 0.36313514128927521]
# ['Hong', 'coffee', 'coffee', 1, 6.1087918281555176, -0.29014110366320267, True, 2.1113669765430174]
# ['Hong', 'coffee', 'coffee', 2, 7.4034759998321533, -0.15183150450941696, True, 0.24538465953732358]
# Parsing this file: betas/betas_6_B_BETA_table_human_correction_coffee_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 6.13255906]
# Beta values: [[ 0.05530509  0.07293204]]
# Updates: [[-0.03272032  0.09134223]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_human_correction_coffee_2.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 6.40370798]
# Beta values: [[ 0.3409526   0.11599435  0.84331757]]
# Updates: [[ 0.12111867 -0.17907664  0.38121327]]
#
# ['Erin', 'table', 'coffee', 0, 6.4037079811096191, 0.12111867361377548, False, 0.34095259801626382]
# ['Erin', 'coffee', 'coffee', 0, 6.4037079811096191, -0.17907664220040687, True, 0.1159943450016306]
# ['Erin', 'human', 'coffee', 0, 6.4037079811096191, 0.38121326690631463, False, 0.84331756649650402]
# Parsing this file: betas/betas_9_B_BETA_table_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 5.71461987  6.39959502]
# Beta values: [[ 1.09228768]
#  [ 7.90473035]]
# Updates: [[-0.32543727]
#  [-0.24285003]]
#
# ['Erin', 'table', 'table', 0, 5.7146198749542236, -0.32543727129313282, True, 1.0922876842650526]
# ['Erin', 'table', 'table', 1, 6.3995950222015381, -0.24285003258542481, True, 7.9047303488352449]
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 4.89826584]
# Beta values: [[ 0.00956759  0.51689481]]
# Updates: [[-0.02502155 -0.3140008 ]]
#
# ['Mitch', 'human', 'human', 0, 4.8982658386230469, -0.31400080399871655, True, 0.51689480990722636]
# Parsing this file: betas/betas_5_B_BETA_table_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 3.65926886  4.32385492  5.04012585]
# Beta values: [[ 0.07326914]
#  [ 0.00299419]
#  [ 0.00234854]]
# Updates: [[-0.19217545]
#  [-0.13965724]
#  [-0.01012435]]
#
# ['Ellis', 'table', 'human', 0, 3.659268856048584, -0.19217545311669681, False, 0.073269137911773863]
# ['Ellis', 'table', 'human', 1, 4.323854923248291, -0.13965723519519102, False, 0.0029941914712322544]
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 6.5389092]
# Beta values: [[ 0.00408733  0.51400389]]
# Updates: [[ 0.05660246 -0.54677858]]
#
# ['Smitha', 'human', 'table', 0, 6.5389091968536377, -0.54677858335109875, False, 0.51400389433582727]
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 5.49927187]
# Beta values: [[ 21.79807559   0.04796284]]
# Updates: [[ 0.46893823 -0.30209034]]
#
# ['Eli', 'table', 'accident', 0, 5.4992718696594238, 0.46893823216126762, False, 21.798075591243332]
# ['Eli', 'coffee', 'accident', 0, 5.4992718696594238, -0.30209033628284487, False, 0.047962836855014117]
# Parsing this file: betas/betas_5_B_BETA_table_human_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 6.10233808]
# Beta values: [[ 0.11139466  0.13665966]]
# Updates: [[ 0.20139336 -0.56607708]]
#
# ['Ellis', 'table', 'accident', 0, 6.1023380756378174, 0.20139335806536351, False, 0.11139465856996522]
# ['Ellis', 'human', 'accident', 0, 6.1023380756378174, -0.56607708300936466, False, 0.13665966125770398]
# Parsing this file: betas/betas_6_B_BETA_human_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 7.90090895]
# Beta values: [[ 2.36151192]]
# Updates: [[-1.23180412]]
#
# ['Steven', 'human', 'human', 0, 7.9009089469909668, -1.2318041171839162, True, 2.3615119243587026]
# Parsing this file: betas/betas_9_B_BETA_table_coffee_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 6.44370794]
# Beta values: [[ 1.88992051  0.03360689]]
# Updates: [[-0.32773312  0.19312553]]
#
# ['Erin', 'table', 'table', 0, 6.4437079429626465, -0.32773311976048092, True, 1.8899205058977542]
# ['Erin', 'coffee', 'table', 0, 6.4437079429626465, 0.19312552990806608, False, 0.03360689120959056]
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_table_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 5.13278389  6.13062286]
# Beta values: [[ 0.09384413]
#  [ 0.01716567]]
# Updates: [[ 0.17569957]
#  [ 0.10098377]]
#
# ['Andreea', 'coffee', 'table', 0, 5.1327838897705078, 0.17569957482707821, False, 0.093844131532418856]
# ['Andreea', 'coffee', 'table', 1, 6.1306228637695312, 0.10098376843790646, False, 0.017165669943447839]
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 17.77858305]
# Beta values: [[ 0.0130173   0.00917095  2.05345776]]
# Updates: [[-0.06245304 -0.09661978 -0.83141401]]
#
# ['Andreea', 'human', 'human', 0, 17.77858304977417, -0.83141401472609289, True, 2.0534577575766826]
# Parsing this file: betas/betas_5_B_BETA_table_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 2.97952199  3.63987899  4.44158101  5.14823508]
# Beta values: [[ 0.11382347]
#  [ 0.04603248]
#  [ 0.00484301]
#  [ 0.11027441]]
# Updates: [[-0.05749421]
#  [ 0.18815208]
#  [-0.0950627 ]
#  [-0.06043515]]
#
# ['Ellis', 'table', 'coffee', 1, 3.6398789882659912, 0.18815208114146031, False, 0.046032476323028058]
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 3.86440492]
# Beta values: [[ 0.00283441  0.00478036]]
# Updates: [[ 0.01926882 -0.04989254]]
#
# Parsing this file: betas/betas_3_B_BETA_table_correction_coffee_1.p
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 4.54915309  5.22946501]
# Beta values: [[ 0.01789008]
#  [ 0.08358689]]
# Updates: [[ 0.027644  ]
#  [ 0.09426507]]
#
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 3.5102129   5.01025701]
# Beta values: [[ 0.03308421  0.45447807]
#  [ 0.23002785  0.03761665]]
# Updates: [[-0.02876013 -0.17228468]
#  [ 0.21308652 -0.20668132]]
#
# ['Eli', 'coffee', 'coffee', 0, 3.5102128982543945, -0.17228467863997565, True, 0.45447806678417813]
# ['Eli', 'table', 'coffee', 1, 5.0102570056915283, 0.21308651508456222, False, 0.2300278516173912]
# ['Eli', 'coffee', 'coffee', 1, 5.0102570056915283, -0.20668132403695694, True, 0.037616649083636093]
# Parsing this file: betas/betas_6_B_BETA_coffee_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [  8.04091001   9.03660893  10.07858896]
# Beta values: [[ 0.01131488]
#  [ 0.01424688]
#  [ 0.01539759]]
# Updates: [[ 0.08223171]
#  [ 0.12636006]
#  [ 0.07650496]]
#
# ['Steven', 'coffee', 'table', 1, 9.0366089344024658, 0.12636006457736215, False, 0.014246881209136017]
# Parsing this file: betas/betas_9_B_BETA_table_correction_accident_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 2.57501292  3.24969387]
# Beta values: [[ 0.57714105]
#  [ 0.07845336]]
# Updates: [[ 0.48034507]
#  [ 0.15110684]]
#
# ['Erin', 'table', 'accident', 0, 2.5750129222869873, 0.48034506830475365, False, 0.57714104891154383]
# ['Erin', 'table', 'accident', 1, 3.2496938705444336, 0.15110683547064241, False, 0.078453359097262504]
# Parsing this file: betas/betas_1_B_BETA_table_coffee_correction_table_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [  9.15174985  10.73673582]
# Beta values: [[ 2.4173015   0.0865074 ]
#  [ 0.5737047   0.02538003]]
# Updates: [[-0.24562917  0.19031574]
#  [-0.16814646  0.09682445]]
#
# ['Andrea', 'table', 'table', 0, 9.151749849319458, -0.24562917483477875, True, 2.4173015037526939]
# ['Andrea', 'coffee', 'table', 0, 9.151749849319458, 0.19031573666907775, False, 0.08650740044323367]
# ['Andrea', 'table', 'table', 1, 10.736735820770264, -0.16814645509000137, True, 0.57370470228562931]
# Parsing this file: betas/betas_8_B_BETA_table_correction_coffee_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 3.2080009   3.87554097  4.53970289  5.18791699]
# Beta values: [[ 0.62941505]
#  [ 0.80096977]
#  [ 0.4639498 ]
#  [ 1.31006899]]
# Updates: [[ 0.13338685]
#  [ 0.20721186]
#  [ 0.22178703]
#  [ 0.23451876]]
#
# ['Simon', 'table', 'coffee', 0, 3.2080008983612061, 0.13338685193034294, False, 0.62941504730422282]
# ['Simon', 'table', 'coffee', 1, 3.8755409717559814, 0.20721186021867766, False, 0.80096977221366195]
# ['Simon', 'table', 'coffee', 2, 4.5397028923034668, 0.22178702507316927, False, 0.46394979666297881]
# ['Simon', 'table', 'coffee', 3, 5.1879169940948486, 0.23451875657396926, False, 1.3100689868201154]
# Parsing this file: betas/betas_2_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 10.99841785]
# Beta values: [[ 1.12267842  0.0980976   0.03060324]]
# Updates: [[-0.29569822  0.28776076  0.21329026]]
#
# ['Eli', 'table', 'table', 0, 10.998417854309082, -0.29569821846193989, True, 1.1226784225738569]
# ['Eli', 'coffee', 'table', 0, 10.998417854309082, 0.28776076475960366, False, 0.098097598260252009]
# ['Eli', 'human', 'table', 0, 10.998417854309082, 0.2132902596462003, False, 0.030603244814641734]
# Parsing this file: betas/betas_8_B_BETA_human_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [  5.791646   10.7582531]
# Beta values: [[  1.60914610e+00]
#  [  6.19507986e-09]]
# Updates: [[-0.85781188]
#  [-0.03441555]]
#
# ['Simon', 'human', 'table', 0, 5.7916460037231445, -0.85781188484519788, False, 1.6091461006015118]
# Parsing this file: betas/betas_4_B_BETA_human_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 6.56082082]
# Beta values: [[ 0.82982608]]
# Updates: [[-0.57751151]]
#
# ['Hong', 'human', 'human', 0, 6.5608208179473877, -0.5775115141038718, True, 0.8298260834134018]
# Parsing this file: betas/betas_7_B_BETA_table_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 2.43926787]
# Beta values: [[ 0.01271538]]
# Updates: [[ 0.03265538]]
#
# Parsing this file: betas/betas_8_B_BETA_table_coffee_correction_accident_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.05233788]
# Beta values: [[ 0.00247595  0.02294269]]
# Updates: [[ 0.07986916 -0.46664578]]
#
# ['Simon', 'coffee', 'accident', 0, 4.0523378849029541, -0.46664577808143548, False, 0.022942692277037213]
# Parsing this file: betas/betas_10_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 3.00112915  4.409729    5.68618298]
# Beta values: [[ 0.20506029  0.65919905]
#  [ 0.06866945  0.02259351]
#  [ 0.16354007  0.1745467 ]]
# Updates: [[ 0.06972988 -0.17322517]
#  [-0.06330244 -0.07328644]
#  [-0.07547217 -0.16377638]]
#
# ['Mitch', 'coffee', 'coffee', 0, 3.001129150390625, -0.17322516581956648, True, 0.65919904589256606]
# ['Mitch', 'coffee', 'coffee', 2, 5.686182975769043, -0.16377637663638467, True, 0.17454669973463494]
# Parsing this file: betas/betas_0_B_BETA_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [  8.12556005  12.430269  ]
# Beta values: [[ 2.60213422]
#  [ 2.33370445]]
# Updates: [[ 0.69697412]
#  [ 0.98735664]]
#
# ['Andreea', 'human', 'accident', 0, 8.1255600452423096, 0.69697412184908103, False, 2.602134221124289]
# ['Andreea', 'human', 'accident', 1, 12.430269002914429, 0.98735663833456755, False, 2.3337044493910319]
# Parsing this file: betas/betas_5_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 12.7094481]
# Beta values: [[ 0.02812022  0.1192604 ]]
# Updates: [[-0.23117331 -0.53099065]]
#
# ['Ellis', 'coffee', 'accident', 0, 12.709448099136353, -0.23117330912157996, False, 0.028120215815847532]
# ['Ellis', 'human', 'accident', 0, 12.709448099136353, -0.5309906475370596, False, 0.11926040217698138]
# Parsing this file: betas/betas_7_B_BETA_human_correction_coffee_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 8.07727599]
# Beta values: [[ 0.07200012]]
# Updates: [[ 0.08821682]]
#
# Parsing this file: betas/betas_10_B_BETA_table_coffee_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 4.11496615  6.14362812]
# Beta values: [[ 0.01231421  0.00330326]
#  [ 0.00209996  0.00119381]]
# Updates: [[-0.02607535 -0.02836631]
#  [-0.01849677  0.02799217]]
#
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 4.23987794  4.84337711  5.46587014  6.08586192  6.68076992]
# Beta values: [[ 0.28921093]
#  [ 5.1080814 ]
#  [ 4.18863822]
#  [ 0.77247214]
#  [ 0.40375238]]
# Updates: [[-0.18423835]
#  [-0.37085413]
#  [-0.30615229]
#  [-0.2342337 ]
#  [-0.19851643]]
#
# ['Andrea', 'coffee', 'coffee', 0, 4.2398779392242432, -0.18423834863387611, True, 0.28921092909406143]
# ['Andrea', 'coffee', 'coffee', 1, 4.8433771133422852, -0.37085412972244924, True, 5.1080814033003197]
# ['Andrea', 'coffee', 'coffee', 2, 5.4658701419830322, -0.30615229422570778, True, 4.188638220205287]
# ['Andrea', 'coffee', 'coffee', 3, 6.0858619213104248, -0.23423369971743213, True, 0.77247214299869837]
# ['Andrea', 'coffee', 'coffee', 4, 6.6807699203491211, -0.19851643163045551, True, 0.40375238275793102]
# Parsing this file: betas/betas_7_B_BETA_table_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 6.91537595]
# Beta values: [[  6.00593512e-04   4.94255065e+00]]
# Updates: [[-0.02307377 -1.53379707]]
#
# ['Smitha', 'human', 'accident', 0, 6.9153759479522705, -1.5337970711702624, False, 4.9425506474674341]
# Parsing this file: betas/betas_4_B_BETA_coffee_human_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 9.09639502]
# Beta values: [[ 0.00427174  0.67292556]]
# Updates: [[-0.05349769 -0.55025851]]
#
# ['Hong', 'human', 'human', 0, 9.0963950157165527, -0.55025851148989346, True, 0.67292555952596544]
# Parsing this file: betas/betas_7_B_BETA_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 6.57056499]
# Beta values: [[ 4.94995176]]
# Updates: [[-1.53379707]]
#
# ['Smitha', 'human', 'accident', 0, 6.5705649852752686, -1.5337970711702624, False, 4.9499517579523564]
# Parsing this file: betas/betas_11_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 4.23553109]
# Beta values: [[ 0.00586123  1.15379034]]
# Updates: [[ 0.01741333 -0.28012934]]
#
# ['Elizabeth', 'coffee', 'coffee', 0, 4.2355310916900635, -0.28012934499992781, True, 1.1537903408951038]
# Parsing this file: betas/betas_6_B_BETA_table_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 7.70412207  8.36614394  9.02233696  9.72377205]
# Beta values: [[ 0.32254349]
#  [ 0.28252676]
#  [ 0.59016674]
#  [ 0.13623812]]
# Updates: [[-0.17728951]
#  [-0.20974616]
#  [-0.2725731 ]
#  [-0.10319681]]
#
# ['Steven', 'table', 'table', 0, 7.7041220664978027, -0.17728950868447413, True, 0.32254349018090073]
# ['Steven', 'table', 'table', 1, 8.3661439418792725, -0.20974616300969018, True, 0.28252675631994317]
# ['Steven', 'table', 'table', 2, 9.0223369598388672, -0.27257310219214226, True, 0.59016674185014317]
# ['Steven', 'table', 'table', 3, 9.7237720489501953, -0.10319681417689353, True, 0.13623811965755506]
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 11.88504601]
# Beta values: [[ 0.0074629  0.       ]]
# Updates: [[-0.09661978 -0.83141401]]
#
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 12.5428021]
# Beta values: [[ 0.00112282  0.        ]]
# Updates: [[-0.0289123   0.68299719]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 6.27284288]
# Beta values: [[ 0.34265518  0.00935428]]
# Updates: [[-0.23625293  0.09544321]]
#
# ['Ellis', 'table', 'table', 0, 6.2728428840637207, -0.23625293086376686, True, 0.34265518414206736]
# Parsing this file: betas/betas_3_B_BETA_table_coffee_correction_coffee_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 5.2216382]
# Beta values: [[ 0.01997213  1.48313156]]
# Updates: [[ 0.02719001 -0.25117555]]
#
# ['Ravi', 'coffee', 'coffee', 0, 5.2216382026672363, -0.25117554896961991, True, 1.4831315600081585]
# Parsing this file: betas/betas_11_B_BETA_coffee_human_correction_table_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 10.49706411]
# Beta values: [[ 0.0849885   0.00394771]]
# Updates: [[ 0.35455035  0.0980833 ]]
#
# ['Elizabeth', 'coffee', 'table', 0, 10.497064113616943, 0.35455035300795146, False, 0.084988497986004399]
# Parsing this file: betas/betas_10_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 14.36550403]
# Beta values: [[ 0.01229829  0.00368767  0.58426809]]
# Updates: [[-0.02607535 -0.02836631 -0.2949893 ]]
#
# ['Mitch', 'human', 'human', 0, 14.365504026412964, -0.29498929612982039, True, 0.58426809066713303]
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_coffee_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 8.238451]
# Beta values: [[ 0.16752966  0.25979918]]
# Updates: [[ 0.06948522  0.1899676 ]]
#
# ['Mitch', 'human', 'coffee', 0, 8.2384510040283203, 0.18996759789622075, False, 0.25979918094021826]
# Parsing this file: betas/betas_9_B_BETA_human_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 4.20352006]
# Beta values: [[ 1.37712068]]
# Updates: [[-0.72279712]]
#
# ['Erin', 'human', 'human', 0, 4.2035200595855713, -0.72279711839241045, True, 1.3771206796682001]
# Parsing this file: betas/betas_8_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 15.66638088]
# Beta values: [[  2.12291331e-03   9.83937264e-03   2.96764761e+00]]
# Updates: [[-0.03337413 -0.15521387 -1.17941682]]
#
# ['Simon', 'coffee', 'human', 0, 15.666380882263184, -0.15521386752609345, False, 0.0098393726434827817]
# ['Simon', 'human', 'human', 0, 15.666380882263184, -1.1794168195389432, True, 2.9676476078286385]
# Parsing this file: betas/betas_5_B_BETA_human_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 11.25964093]
# Beta values: [[ 0.66354337]]
# Updates: [[-0.65661677]]
#
# ['Ellis', 'human', 'table', 0, 11.25964093208313, -0.65661676588477391, False, 0.66354337078521086]
# Parsing this file: betas/betas_11_B_BETA_table_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 3.59900808  4.24850512]
# Beta values: [[ 0.0066001 ]
#  [ 0.01022674]]
# Updates: [[ 0.01882468]
#  [-0.06654824]]
#
# Parsing this file: betas/betas_7_B_BETA_coffee_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 2.73651099]
# Beta values: [[ 0.01802615]]
# Updates: [[-0.07606484]]
#
# Parsing this file: betas/betas_5_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 13.61583805]
# Beta values: [[  8.25813392e-02   9.22763914e-04   3.23697966e+00]]
# Updates: [[-0.19714417 -0.04805459 -1.20384052]]
#
# ['Ellis', 'table', 'human', 0, 13.615838050842285, -0.19714417014456131, False, 0.082581339176545795]
# ['Ellis', 'human', 'human', 0, 13.615838050842285, -1.203840518327091, True, 3.2369796558959836]
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 5.13953805  9.97576499]
# Beta values: [[ 0.00106148]
#  [ 0.04363003]]
# Updates: [[-0.0289123 ]
#  [ 0.18217064]]
#
# ['Andreea', 'coffee', 'accident', 1, 9.9757649898529053, 0.18217063914005394, False, 0.043630032719685227]
# Parsing this file: betas/betas_0_B_BETA_coffee_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 3.95208001]
# Beta values: [[ 0.00805163]]
# Updates: [[-0.09661978]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 4.32814312]
# Beta values: [[ 0.00528057  0.02142578]]
# Updates: [[ 0.03402593 -0.14165144]]
#
# ['Erin', 'coffee', 'human', 0, 4.3281431198120117, -0.14165144041125899, False, 0.021425780811364648]
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [  7.95195103  16.95473981]
# Beta values: [[  1.86849496e-01   1.27940234e-03   1.97202145e+00]
#  [  2.04696032e-03   2.65542017e-02   6.67628372e-01]]
# Updates: [[ 0.15804485 -0.0289123   0.68299719]
#  [-0.02555654  0.19403331  0.9878667 ]]
#
# ['Andreea', 'table', 'accident', 0, 7.9519510269165039, 0.15804484797257601, False, 0.18684949647840907]
# ['Andreea', 'human', 'accident', 0, 7.9519510269165039, 0.68299718541594956, False, 1.9720214516673129]
# ['Andreea', 'coffee', 'accident', 1, 16.954739809036255, 0.19403331011558578, False, 0.02655420170420511]
# ['Andreea', 'human', 'accident', 1, 16.954739809036255, 0.98786670080292893, False, 0.66762837195130009]
# Parsing this file: betas/betas_2_B_BETA_table_coffee_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 3.69824004  5.0824492 ]
# Beta values: [[  1.03231109e+00   1.12607975e-01]
#  [  1.56973620e-01   2.67601948e-05]]
# Updates: [[-0.29569822  0.28776076]
#  [-0.19544136  0.00599685]]
#
# ['Eli', 'table', 'table', 0, 3.6982400417327881, -0.29569821846193989, True, 1.032311087624401]
# ['Eli', 'coffee', 'table', 0, 3.6982400417327881, 0.28776076475960366, False, 0.11260797467219288]
# ['Eli', 'table', 'table', 1, 5.082449197769165, -0.19544136029423775, True, 0.15697361953356681]
# Parsing this file: betas/betas_0_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Andreea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 14.23755002]
# Beta values: [[ 0.89849666  0.09342132  0.        ]]
# Updates: [[-0.1793054   0.17569957  0.10679792]]
#
# ['Andreea', 'table', 'table', 0, 14.237550020217896, -0.17930540194284461, True, 0.89849665686227276]
# ['Andreea', 'coffee', 'table', 0, 14.237550020217896, 0.17569957482707821, False, 0.093421318923300772]
# Parsing this file: betas/betas_11_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 10.16688704]
# Beta values: [[ 0.00580096  1.2431154   0.        ]]
# Updates: [[ 0.01741333 -0.28012934 -0.14482644]]
#
# ['Elizabeth', 'coffee', 'coffee', 0, 10.166887044906616, -0.28012934499992781, True, 1.2431153970190068]
# Parsing this file: betas/betas_5_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 11.38572192]
# Beta values: [[ 0.12902249  0.46030929]]
# Updates: [[-0.12503577 -0.23947359]]
#
# ['Ellis', 'coffee', 'coffee', 0, 11.385721921920776, -0.12503577496229923, True, 0.12902249492996543]
# ['Ellis', 'human', 'coffee', 0, 11.385721921920776, -0.23947359095041065, False, 0.46030929126658038]
# Parsing this file: betas/betas_1_B_BETA_coffee_correction_accident_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 3.58727503  5.2572701   5.98056507  7.04615211  7.9509232 ]
# Beta values: [[ 0.22412507]
#  [ 0.03719831]
#  [ 0.01615582]
#  [ 0.08706367]
#  [ 0.02072352]]
# Updates: [[-0.20410638]
#  [-0.37636018]
#  [-0.1404186 ]
#  [ 0.32729816]
#  [ 0.08987239]]
#
# ['Andrea', 'coffee', 'accident', 0, 3.5872750282287598, -0.20410637511925245, False, 0.22412506703302071]
# ['Andrea', 'coffee', 'accident', 1, 5.2572700977325439, -0.37636018128861792, False, 0.037198309713700202]
# ['Andrea', 'coffee', 'accident', 2, 5.980565071105957, -0.14041859655290523, False, 0.016155817520640468]
# ['Andrea', 'coffee', 'accident', 3, 7.0461521148681641, 0.327298159739982, False, 0.087063672501722825]
# Parsing this file: betas/betas_6_B_BETA_human_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 15.28808689]
# Beta values: [[ 1.00931026]]
# Updates: [[-0.48428202]]
#
# ['Steven', 'human', 'table', 0, 15.288086891174316, -0.48428202417733957, False, 1.0093102557691873]
# Parsing this file: betas/betas_11_B_BETA_table_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.75199008]
# Beta values: [[ 0.8995272   0.16736991]]
# Updates: [[-0.30346572 -0.46883259]]
#
# ['Elizabeth', 'table', 'accident', 0, 4.7519900798797607, -0.30346572280666351, False, 0.8995272045162358]
# ['Elizabeth', 'human', 'accident', 0, 4.7519900798797607, -0.46883258614645129, False, 0.16736991369081788]
# Parsing this file: betas/betas_9_B_BETA_table_correction_human_1.p
# Name of human: Erin
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 2.97778392  3.64019799  4.34102392]
# Beta values: [[ 0.00656923]
#  [ 0.00525125]
#  [ 0.00871116]]
# Updates: [[ 0.03695454]
#  [ 0.10904398]
#  [ 0.01627617]]
#
# ['Erin', 'table', 'human', 1, 3.6401979923248291, 0.10904397624770468, False, 0.005251245572280322]
# Parsing this file: betas/betas_4_B_BETA_coffee_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 3.82252312  4.43909311  5.04638195  5.66480398  6.27103996  6.88247609]
# Beta values: [[ 0.53588777]
#  [ 2.35324308]
#  [ 2.8391478 ]
#  [ 3.14068315]
#  [ 1.71423977]
#  [ 0.08235117]]
# Updates: [[-0.28420472]
#  [-0.30743973]
#  [-0.27578669]
#  [-0.25959443]
#  [-0.19463709]
#  [-0.12081858]]
#
# ['Hong', 'coffee', 'coffee', 0, 3.8225231170654297, -0.2842047222855939, True, 0.53588777386697928]
# ['Hong', 'coffee', 'coffee', 1, 4.4390931129455566, -0.30743973397486712, True, 2.3532430802952704]
# ['Hong', 'coffee', 'coffee', 2, 5.046381950378418, -0.27578668934901174, True, 2.839147802163863]
# ['Hong', 'coffee', 'coffee', 3, 5.6648039817810059, -0.25959442929176291, True, 3.1406831459174929]
# ['Hong', 'coffee', 'coffee', 4, 6.2710399627685547, -0.19463708884569897, True, 1.7142397687151876]
# ['Hong', 'coffee', 'coffee', 5, 6.8824760913848877, -0.12081857932567885, True, 0.08235116704243578]
# Parsing this file: betas/betas_10_B_BETA_table_human_correction_table_1.p
# Name of human: Mitch
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 4.56903601]
# Beta values: [[ 0.71344143  0.16023566]]
# Updates: [[-0.21059087 -0.33710002]]
#
# ['Mitch', 'table', 'table', 0, 4.5690360069274902, -0.21059086695057161, True, 0.71344143031730167]
# ['Mitch', 'human', 'table', 0, 4.5690360069274902, -0.33710002437587505, False, 0.16023566018480404]
# Parsing this file: betas/betas_5_B_BETA_table_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 4.87937284  5.600595    6.26461887]
# Beta values: [[ 0.38855787]
#  [ 0.21180252]
#  [ 2.03257722]]
# Updates: [[-0.23242398]
#  [-0.80467106]
#  [ 0.35343772]]
#
# ['Ellis', 'table', 'table', 0, 4.8793728351593018, -0.2324239799861445, True, 0.38855786689333149]
# ['Ellis', 'table', 'table', 1, 5.6005949974060059, -0.80467106216537942, True, 0.21180251828640573]
# ['Ellis', 'table', 'table', 2, 6.2646188735961914, 0.35343772100483051, True, 2.0325772155938773]
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_human_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 9.83605909]
# Beta values: [[ 0.01802437  0.51787908]]
# Updates: [[-0.07606484 -0.36126237]]
#
# ['Smitha', 'human', 'human', 0, 9.8360590934753418, -0.36126237031106712, True, 0.51787908281375949]
# Parsing this file: betas/betas_2_B_BETA_coffee_correction_accident_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.18040705  4.88212705  5.57953095]
# Beta values: [[ 0.04871553]
#  [ 0.03433693]
#  [ 0.02566303]]
# Updates: [[-0.30209034]
#  [-0.45930606]
#  [-0.09163078]]
#
# ['Eli', 'coffee', 'accident', 0, 4.1804070472717285, -0.30209033628284487, False, 0.048715526397996901]
# ['Eli', 'coffee', 'accident', 1, 4.882127046585083, -0.45930605676690561, False, 0.034336930036036571]
# Parsing this file: betas/betas_3_B_BETA_coffee_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.57986093]
# Beta values: [[ 0.00875912]]
# Updates: [[-0.21903556]]
#
# ['Ravi', 'coffee', 'accident', 0, 4.5798609256744385, -0.21903555606947833, False, 0.0087591246703141723]
# Parsing this file: betas/betas_6_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 16.81184602]
# Beta values: [[ 0.03257315  1.15533849]]
# Updates: [[-0.83790302 -3.68466388]]
#
# ['Steven', 'coffee', 'accident', 0, 16.811846017837524, -0.83790301535192668, False, 0.032573153007894304]
# ['Steven', 'human', 'accident', 0, 16.811846017837524, -3.6846638808123586, False, 1.1553384911053552]
# Parsing this file: betas/betas_3_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 7.66919112]
# Beta values: [[  9.47201224e-03   9.50345125e+00]]
# Updates: [[-0.22654306 -1.94499804]]
#
# ['Ravi', 'coffee', 'accident', 0, 7.6691911220550537, -0.22654305661540519, False, 0.009472012235845529]
# ['Ravi', 'human', 'accident', 0, 7.6691911220550537, -1.94499803703048, False, 9.5034512450244275]
# Parsing this file: betas/betas_3_B_BETA_table_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 4.18567991]
# Beta values: [[ 0.00102173]]
# Updates: [[-0.03559949]]
#
# Parsing this file: betas/betas_9_B_BETA_table_human_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 11.13614893]
# Beta values: [[ 0.33461889  1.62920841]]
# Updates: [[ 0.12037325  0.39062223]]
#
# ['Erin', 'table', 'coffee', 0, 11.136148929595947, 0.12037324705141472, False, 0.33461888810331486]
# ['Erin', 'human', 'coffee', 0, 11.136148929595947, 0.39062223368436477, False, 1.6292084072283888]
# Parsing this file: betas/betas_8_B_BETA_table_correction_table_1.p
# Name of human: Simon
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 4.58321285  5.25314188  5.91603804  6.60773587  7.25625706  7.92198801]
# Beta values: [[ 0.01528994]
#  [ 0.30579846]
#  [ 0.90036708]
#  [ 0.32423222]
#  [ 0.46119263]
#  [ 0.89103709]]
# Updates: [[-0.06596263]
#  [-0.17734727]
#  [-0.2733325 ]
#  [-0.1796483 ]
#  [-0.31027872]
#  [-0.18803454]]
#
# ...
# Name of human: Ravi
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 2.91538     3.58721185  4.24401093]
# Beta values: [[ 0.04233145]
#  [ 0.00025613]
#  [ 0.00988406]]
# Updates: [[-0.0943054 ]
#  [ 0.0090624 ]
#  [ 0.02679099]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_correction_coffee_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 4.75472999  5.36621499  5.97515082]
# Beta values: [[ 0.17692591]
#  [ 4.51580093]
#  [ 1.38302222]]
# Updates: [[-0.10456085]
#  [-0.44563311]
#  [-0.4925748 ]]
#
# ['Steven', 'coffee', 'coffee', 0, 4.7547299861907959, -0.1045608460890719, True, 0.1769259078274126]
# ['Steven', 'coffee', 'coffee', 1, 5.3662149906158447, -0.44563311221101287, True, 4.5158009333238267]
# ['Steven', 'coffee', 'coffee', 2, 5.9751508235931396, -0.49257480278052768, True, 1.383022217729708]
# Parsing this file: betas/betas_9_B_BETA_coffee_human_correction_table_1.p
# Name of human: Erin
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 14.22966909]
# Beta values: [[ 0.03377355  0.14774671]]
# Updates: [[ 0.19312553 -0.45324319]]
#
# ['Erin', 'coffee', 'table', 0, 14.229669094085693, 0.19312552990806608, False, 0.033773547354974912]
# ['Erin', 'human', 'table', 0, 14.229669094085693, -0.45324319350620357, False, 0.14774671392192809]
# Parsing this file: betas/betas_2_B_BETA_coffee_human_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 11.301548]
# Beta values: [[ 0.00568473  0.        ]]
# Updates: [[-0.04989254 -0.41922024]]
#
# Parsing this file: betas/betas_3_B_BETA_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 9.5339911]
# Beta values: [[ 0.]]
# Updates: [[-1.96454967]]
#
# Parsing this file: betas/betas_0_B_BETA_table_correction_coffee_1.p
# Name of human: Andreea
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 4.30439401  4.98304081  5.68706989]
# Beta values: [[ 0.09317148]
#  [ 0.0125649 ]
#  [ 0.00857214]]
# Updates: [[-0.07124415]
#  [-0.05290162]
#  [ 0.03495797]]
#
# Parsing this file: betas/betas_5_B_BETA_coffee_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 5.23480415  6.23839903]
# Beta values: [[ 0.00873864]
#  [ 0.09132574]]
# Updates: [[ 0.09544321]
#  [ 0.80289033]]
#
# ['Ellis', 'coffee', 'table', 1, 6.2383990287780762, 0.80289032991954912, False, 0.091325744271976095]
# Parsing this file: betas/betas_5_B_BETA_table_human_correction_table_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 12.63113284]
# Beta values: [[ 0.38264554  0.61148834]]
# Updates: [[-0.23242398 -0.65661677]]
#
# ['Ellis', 'table', 'table', 0, 12.631132841110229, -0.2324239799861445, True, 0.38264554410812845]
# ['Ellis', 'human', 'table', 0, 12.631132841110229, -0.65661676588477391, False, 0.61148833966302707]
# Parsing this file: betas/betas_4_B_BETA_human_correction_coffee_1.p
# Name of human: Hong
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? False
# Timestamp of pushes: [ 8.01583004]
# Beta values: [[ 0.21068474]]
# Updates: [[-0.29577947]]
#
# ['Hong', 'human', 'coffee', 0, 8.0158300399780273, -0.29577946946908895, False, 0.21068474354812164]
# Parsing this file: betas/betas_0_B_BETA_human_correction_human_1.p
# Name of human: Andreea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 8.38832712]
# Beta values: [[ 2.08240225]]
# Updates: [[-0.86202889]]
#
# ['Andreea', 'human', 'human', 0, 8.3883271217346191, -0.86202888916427867, True, 2.0824022452083808]
# Parsing this file: betas/betas_11_B_BETA_human_correction_accident_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 10.83191085]
# Beta values: [[ 0.19313261]]
# Updates: [[-0.46883259]]
#
# ['Elizabeth', 'human', 'accident', 0, 10.831910848617554, -0.46883258614645129, False, 0.19313261475115986]
# Parsing this file: betas/betas_6_B_BETA_table_coffee_human_correction_table_1.p
# Name of human: Steven
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 15.33631706]
# Beta values: [[ 0.43271442  0.01006264  1.92510036]]
# Updates: [[-0.18111442  0.08223171 -0.47804828]]
#
# ['Steven', 'table', 'table', 0, 15.33631706237793, -0.18111442197629302, True, 0.43271441915224157]
# ['Steven', 'human', 'table', 0, 15.33631706237793, -0.47804828236743191, False, 1.9251003626548921]
# Parsing this file: betas/betas_11_B_BETA_coffee_correction_coffee_1.p
# Name of human: Elizabeth
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 3.54202008  4.16383004]
# Beta values: [[ 1.16220657]
#  [ 0.83325187]]
# Updates: [[-0.28012934]
#  [-0.78355388]]
#
# ['Elizabeth', 'coffee', 'coffee', 0, 3.5420200824737549, -0.28012934499992781, True, 1.1622065678088072]
# ['Elizabeth', 'coffee', 'coffee', 1, 4.163830041885376, -0.78355387950243482, True, 0.83325186671801343]
# Parsing this file: betas/betas_0_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Andreea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 11.78642797]
# Beta values: [[ 0.15507394  0.        ]]
# Updates: [[-0.17278251 -0.25581318]]
#
# ['Andreea', 'coffee', 'coffee', 0, 11.786427974700928, -0.1727825087605197, True, 0.15507394443204325]
# Parsing this file: betas/betas_7_B_BETA_table_coffee_correction_table_1.p
# Name of human: Smitha
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 4.00402904  6.00464797]
# Beta values: [[ 0.27837997  0.00378558]
#  [ 0.30446997  0.01484705]]
# Updates: [[-0.1781826   0.05660246]
#  [-0.18345519  0.09917094]]
#
# ['Smitha', 'table', 'table', 0, 4.0040290355682373, -0.17818260393044838, True, 0.27837997283257393]
# ['Smitha', 'table', 'table', 1, 6.004647970199585, -0.18345519054297021, True, 0.30446997358901456]
# Parsing this file: betas/betas_2_B_BETA_table_human_correction_human_1.p
# Name of human: Eli
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 9.33224607]
# Beta values: [[ 0.00322359  0.50435576]]
# Updates: [[ 0.02037566 -0.44491134]]
#
# ['Eli', 'human', 'human', 0, 9.3322460651397705, -0.44491134343666161, True, 0.50435575922656728]
# Parsing this file: betas/betas_3_B_BETA_table_human_correction_human_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 9.95697904]
# Beta values: [[ 0.04713074  1.17329153]]
# Updates: [[-0.0943054  -0.70097274]]
#
# ['Ravi', 'human', 'human', 0, 9.9569790363311768, -0.70097273633304269, True, 1.1732915347540476]
# Parsing this file: betas/betas_3_B_BETA_table_coffee_correction_table_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 7.08529282]
# Beta values: [[ 3.083713    0.12503708]]
# Updates: [[-0.28470933  0.27925361]]
#
# ['Ravi', 'table', 'table', 0, 7.0852928161621094, -0.28470932953581496, True, 3.0837129985128904]
# ['Ravi', 'coffee', 'table', 0, 7.0852928161621094, 0.27925360602335303, False, 0.12503707896625171]
# Parsing this file: betas/betas_8_B_BETA_table_coffee_correction_human_1.p
# Name of human: Simon
# Robot knew about these features: ['table', 'coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 4.341079]
# Beta values: [[ 0.00188991  0.01012661]]
# Updates: [[-0.03337413 -0.15521387]]
#
# ['Simon', 'coffee', 'human', 0, 4.3410789966583252, -0.15521386752609345, False, 0.010126611477019244]
# Parsing this file: betas/betas_3_B_BETA_table_human_correction_accident_1.p
# Name of human: Ravi
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 8.72467303]
# Beta values: [[  9.31328684e-04   1.04719805e+01]]
# Updates: [[-0.03611006 -1.96454967]]
#
# ['Ravi', 'human', 'accident', 0, 8.7246730327606201, -1.9645496696170852, False, 10.471980508632353]
# Parsing this file: betas/betas_5_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Ellis
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 9.60011506]
# Beta values: [[ 0.11841538  0.11706825  0.45761795]]
# Updates: [[-0.05828946 -0.12503577 -0.23947359]]
#
# ['Ellis', 'coffee', 'coffee', 0, 9.6001150608062744, -0.12503577496229923, True, 0.11706825472432703]
# ['Ellis', 'human', 'coffee', 0, 9.6001150608062744, -0.23947359095041065, False, 0.45761794990471694]
# Parsing this file: betas/betas_4_B_BETA_table_human_correction_table_1.p
# Name of human: Hong
# Robot knew about these features: ['table', 'human']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 17.58365989]
# Beta values: [[ 0.26386715  1.08553542]]
# Updates: [[-0.1399272  -0.42218341]]
#
# ['Hong', 'table', 'table', 0, 17.583659887313843, -0.13992719867997749, True, 0.26386714661157018]
# ['Hong', 'human', 'table', 0, 17.583659887313843, -0.42218341404551651, False, 1.0855354163019473]
# Parsing this file: betas/betas_1_B_BETA_coffee_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 11.12446809]
# Beta values: [[ 0.32108664  0.30121852]]
# Updates: [[-0.18513826 -0.22497674]]
#
# ['Andrea', 'coffee', 'coffee', 0, 11.124468088150024, -0.1851382568229667, True, 0.32108663910678381]
# ['Andrea', 'human', 'coffee', 0, 11.124468088150024, -0.22497673827950138, False, 0.30121852356626416]
# Parsing this file: betas/betas_1_B_BETA_human_correction_table_1.p
# Name of human: Andrea
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['table']
# Was human intentional? False
# Timestamp of pushes: [ 10.60111785]
# Beta values: [[ 0.03815203]]
# Updates: [[-0.16582122]]
#
# ['Andrea', 'human', 'table', 0, 10.601117849349976, -0.16582122107695341, False, 0.03815202966966514]
# Parsing this file: betas/betas_1_B_BETA_table_coffee_human_correction_human_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 12.89605403]
# Beta values: [[ 0.03393653  0.0308269   0.        ]]
# Updates: [[ 0.08114473 -0.16043026 -0.60229369]]
#
# ['Andrea', 'coffee', 'human', 0, 12.896054029464722, -0.1604302562924218, False, 0.030826896447775323]
# Parsing this file: betas/betas_2_B_BETA_table_correction_table_1.p
# Name of human: Eli
# Robot knew about these features: ['table']
# Human was asked to correct these features: ['table']
# Was human intentional? True
# Timestamp of pushes: [ 2.93647504  3.65576792  4.32034588]
# Beta values: [[ 0.67683829]
#  [ 7.98485511]
#  [ 0.11221263]]
# Updates: [[-0.29713026]
#  [-0.67536544]
#  [-0.16946112]]
#
# ['Eli', 'table', 'table', 0, 2.9364750385284424, -0.29713026150860955, True, 0.67683828944764146]
# ['Eli', 'table', 'table', 1, 3.6557679176330566, -0.675365440838533, True, 7.9848551088756849]
# ['Eli', 'table', 'table', 2, 4.3203458786010742, -0.16946111618241133, True, 0.11221263407540888]
# Parsing this file: betas/betas_4_B_BETA_coffee_correction_human_1.p
# Name of human: Hong
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['human']
# Was human intentional? False
# Timestamp of pushes: [ 3.86409283  4.88783002  5.91223598]
# Beta values: [[ 0.00426884]
#  [ 0.01611246]
#  [ 0.00253636]]
# Updates: [[-0.05349769]
#  [-0.06294611]
#  [-0.04375976]]
#
# Parsing this file: betas/betas_6_B_BETA_coffee_human_correction_human_1.p
# Name of human: Steven
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 14.24873996]
# Beta values: [[  9.97917313e-04   6.15698493e+00]]
# Updates: [[-0.04953888 -1.18864824]]
#
# ['Steven', 'human', 'human', 0, 14.248739957809448, -1.1886482430580756, True, 6.1569849269785415]
# Parsing this file: betas/betas_10_B_BETA_human_correction_human_1.p
# Name of human: Mitch
# Robot knew about these features: ['human']
# Human was asked to correct these features: ['human']
# Was human intentional? True
# Timestamp of pushes: [ 8.466048]
# Beta values: [[ 0.]]
# Updates: [[-0.3140008]]
#
# Parsing this file: betas/betas_9_B_BETA_table_coffee_human_correction_accident_1.p
# Name of human: Erin
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 13.08458686]
# Beta values: [[ 0.55263288  0.07480218  0.06595864]]
# Updates: [[ 0.47821798 -0.51083758 -0.58363039]]
#
# ['Erin', 'table', 'accident', 0, 13.08458685874939, 0.47821797881114847, False, 0.55263288432129398]
# ['Erin', 'coffee', 'accident', 0, 13.08458685874939, -0.51083758146273794, False, 0.074802180135317461]
# ['Erin', 'human', 'accident', 0, 13.08458685874939, -0.58363039389992366, False, 0.065958641874210147]
# Parsing this file: betas/betas_7_B_BETA_coffee_human_correction_accident_1.p
# Name of human: Smitha
# Robot knew about these features: ['coffee', 'human']
# Human was asked to correct these features: ['accident']
# Was human intentional? False
# Timestamp of pushes: [ 11.85938287]
# Beta values: [[ 0.01320401  0.        ]]
# Updates: [[-0.20705649 -1.50331708]]
#
# ['Smitha', 'coffee', 'accident', 0, 11.85938286781311, -0.20705649467641507, False, 0.013204010568016178]
# Parsing this file: betas/betas_9_B_BETA_coffee_correction_coffee_1.p
# Name of human: Erin
# Robot knew about these features: ['coffee']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 3.14046884  3.78904295]
# Beta values: [[ 0.33885719]
#  [ 0.4935131 ]]
# Updates: [[-0.17907664]
#  [-0.35935325]]
#
# ['Erin', 'coffee', 'coffee', 0, 3.1404688358306885, -0.17907664220040687, True, 0.3388571897472169]
# ['Erin', 'coffee', 'coffee', 1, 3.7890429496765137, -0.35935325193496936, True, 0.49351309890339667]
# Parsing this file: betas/betas_1_B_BETA_table_coffee_human_correction_coffee_1.p
# Name of human: Andrea
# Robot knew about these features: ['table', 'coffee', 'human']
# Human was asked to correct these features: ['coffee']
# Was human intentional? True
# Timestamp of pushes: [ 12.94194603]
# Beta values: [[ 0.00641182  0.39824949  0.        ]]
# Updates: [[-0.01608912 -0.18423835 -0.22175409]]
#
# ['Andrea', 'coffee', 'coffee', 0, 12.941946029663086, -0.18423834863387611, True, 0.39824949026442569]

# %%
# Create P(beta | intent, feature) from data

# intent = false, feature = table
P_beta_00 = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Beta']
update_00 = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Update']

# intent = true, feature = table
P_beta_10 = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Beta']
update_10 = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Update']

# intent = false, feature = coffee
P_beta_01 = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Beta']
update_01 = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Update']

# intent = true, feature = coffee
P_beta_11 = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Beta']
update_11 = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Update']

# intent = false, feature = human
P_beta_02 = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Beta']
update_02 = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] != 'accident')&(df['Intentional'] == False)]['Update']

# intent = true, feature = human
P_beta_12 = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Beta']
update_12 = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] != 'accident')&(df['Intentional'] == True)]['Update']

# %%
def plot_density(data1, data2, num_bins, F, rm_outliers=False, savefig=False):
    import matplotlib
    import os
    
    fig, ax = plt.subplots(figsize=(12, 9))
    indep_color = '#f79646'
    joint_color = '#008080'

    matplotlib.rcParams.update({'font.size': 35})
    
    # the histogram of the data
    weights1 = np.ones_like(data1) / (len(data1))
    weights2 = np.ones_like(data2) / (len(data2))
    bins=np.histogram(np.hstack((data1,data2)), bins=num_bins)[1]
    _, bins1, _ = ax.hist(data1, bins, weights=weights1, facecolor=joint_color, alpha=0.5)
    _, bins2, _ = ax.hist(data2, bins, weights=weights2, facecolor=indep_color, alpha=0.5)

    if rm_outliers:
        data1 = data1[abs(data1 - np.mean(data1)) < 2 * np.std(data1)]
        data2 = data2[abs(data2 - np.mean(data2)) < 2 * np.std(data2)]

    # add a 'best fit' line after rejecting outliers
    df1, loc1, scale1 =  stats.chi2.fit(data1)
    df2, loc2, scale2 =  stats.chi2.fit(data2)
    print df1, loc1, scale1
    print df2, loc2, scale2
    y1 = stats.chi2.pdf(bins1, df1, loc1, scale1)
    y2 = stats.chi2.pdf(bins2, df2, loc2, scale2)

    ax.plot(bins1, y1/sum(y1), '-', color=joint_color, linewidth=5.0)
    ax.plot(bins2, y2/sum(y2), '-', color=indep_color, linewidth=5.0)
    ax.set_xlabel(r'$\hat{\beta}$')
    ax.set_ylabel('Probability density')
    title = r"Empirical $P(\beta|I)$ and $\chi^2$ fit"
    ax.set_title(title)
    ax.legend([r'$P(\beta|I=0)$',r'$P(\beta|I=1)$'])

    # Tweak spacing to prevent clipping of ylabel
    plt.subplots_adjust(left=0.15)
    plt.show()
    
    if savefig:
        fig.savefig("hist_{}.pdf".format(F), bbox_inches="tight")
        print "Saved weights figure."

# %%
plot_density(P_beta_00, P_beta_10, 40, "table", savefig=True)
# Out:
# 1.80041376328 0.00299419147123 0.154878185097
# 1.36737688926 0.112212634075 1.05476238984
# Saved weights figure.

# %%
plot_density(P_beta_01, P_beta_11, 40, "coffee", savefig=True)
# Out:
# 1.62070513714 0.0068617251698 0.0289367690935
# 1.28972898761 0.0376166490836 0.79839944817
# Saved weights figure.

# %%
plot_density(P_beta_02, P_beta_12, 25, "human", savefig=True)
# Out:
# 0.899625418404 0.022880270078 1.29109899886
# 1.79523381954 0.304278367258 0.580684081529
# Saved weights figure.

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# Plot R = table; H = table
t_t = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] == 'table')]['Beta']
t_c = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] == 'coffee')]['Beta']
t_h = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] == 'human')]['Beta']
t_a = df.loc[(df['R_feat'] == 'table')&(df['H_feat'] == 'accident')]['Beta']

c_t = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] == 'table')]['Beta']
c_c = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] == 'coffee')]['Beta']
c_h = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] == 'human')]['Beta']
c_a = df.loc[(df['R_feat'] == 'coffee')&(df['H_feat'] == 'accident')]['Beta']

h_t = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] == 'table')]['Beta']
h_c = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] == 'coffee')]['Beta']
h_h = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] == 'human')]['Beta']
h_a = df.loc[(df['R_feat'] == 'human')&(df['H_feat'] == 'accident')]['Beta']

data = [[np.mean(t_t),np.mean(t_c),np.mean(t_h)],[np.mean(c_t),np.mean(c_c),np.mean(c_h)],[np.mean(h_t),np.mean(h_c),np.mean(h_h)]]

matplotlib.rcParams.update({'font.size': 30})
plt.figure(figsize=(12,10))
sns.heatmap(data,cmap="Blues")
plt.xticks([0.5,1.5,2.5], ["table", "coffee", "human"])
plt.yticks([0.25,1.25,2.25], ["table", "coffee", "human"])
plt.title(r"Average $\beta$")
plt.show()

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig = plt.gcf()
ax1 = plt.subplot2grid((1, 6), (0, 0))
ax2 = plt.subplot2grid((1, 6), (0, 1))
ax3 = plt.subplot2grid((1, 6), (0, 2))

set_style()
relevant_color = '#f79646'
irrelevant_color = '#008080'

##### Table #####
ax1.set_title(r'$\beta_{table}$', fontsize=16, fontweight='normal')
r1 = ax1.bar([0.0], 
             [P_beta_00.mean()], 
             yerr=[P_beta_00.sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [P_beta_10.mean()], 
             yerr=[P_beta_10.sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
plot_sig_line(ax1, 0, 1, 1.65, 0.08)
ax1.set_ylim([0, 2])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([])
# ax1.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Coffee #####
ax2.set_title(r'$\beta_{cup}$', fontsize=16, fontweight='normal')
r1 = ax2.bar([0.0], 
             [P_beta_01.mean()], 
             yerr=[P_beta_01.sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax2.bar([1.0], 
             [P_beta_11.mean()], 
             yerr=[P_beta_11.sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
plot_sig_line(ax2, 0, 1, 1.525, 0.08)
ax2.set_ylim([0, 2])
#ax2.set_xlim([-0.25, 2.25])
plt.sca(ax2)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Human #####
ax3.set_title(r'$\beta_{human}$', fontsize=16, fontweight='normal')
r1 = ax3.bar([0.0], 
             [P_beta_02.mean()], 
             yerr=[P_beta_02.sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax3.bar([1.0], 
             [P_beta_12.mean()], 
             yerr=[P_beta_12.sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
plot_sig_line(ax3, 0, 1, 1.6, 0.07)
ax3.set_ylim([0, 1.9])
#ax3.set_xlim([-0.25, 2.25])
plt.sca(ax3)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

leg = ax3.legend((r1[0], r2[0]), 
                ('Irrelevant $u_H$', 'Relevant $u_H$'), 
                loc='upper right',
                ncol=1, 
                fontsize=11,
                bbox_to_anchor=(2., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(15)
fig.set_figheight(4)

plt.savefig('features_relevant_barplots.pdf', bbox_inches='tight')

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig = plt.gcf()
ax1 = plt.subplot2grid((1, 6), (0, 0))
ax2 = plt.subplot2grid((1, 6), (0, 1))
ax3 = plt.subplot2grid((1, 6), (0, 2))

set_style()
relevant_color = '#f79646'
irrelevant_color = '#008080'

##### Time #####
ax1.set_title(r'$\Delta\phi_{table}$', fontsize=16, fontweight='normal')
r1 = ax1.bar([0.0], 
             [abs(update_00).mean()], 
             yerr=[abs(update_00).sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [abs(update_10).mean()], 
             yerr=[abs(update_10).sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax1, 0, 1, 0.4, 0.05)
ax1.set_ylim([0, 1.1])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([])
# ax1.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Runs #####
ax2.set_title(r'$\Delta\phi_{cup}$', fontsize=16, fontweight='normal')
r1 = ax2.bar([0.0], 
             [abs(update_01).mean()], 
             yerr=[abs(update_01).sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax2.bar([1.0], 
             [abs(update_11).mean()], 
             yerr=[abs(update_11).sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax2, 0, 1, 0.4, 0.05)
ax2.set_ylim([0, 1.1])
#ax2.set_xlim([-0.25, 2.25])
plt.sca(ax2)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Ease of use #####
ax3.set_title(r'$\Delta\phi_{human}$', fontsize=16, fontweight='normal')
r1 = ax3.bar([0.0], 
             [abs(update_02).mean()], 
             yerr=[abs(update_02).sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax3.bar([1.0], 
             [abs(update_12).mean()], 
             yerr=[abs(update_12).sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax3, 0, 1, 0.85, 0.05)
ax3.set_ylim([0, 1.1])
#ax3.set_xlim([-0.25, 2.25])
plt.sca(ax3)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

leg = ax3.legend((r1[0], r2[0]), 
                ('Irrelevant $u_H$', 'Relevant $u_H$'), 
                loc='upper right',
                ncol=1, 
                fontsize=11,
                bbox_to_anchor=(2., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(15)
fig.set_figheight(4)

plt.savefig('update_relevant_barplots.pdf', bbox_inches='tight')

# %%
# fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
fig = plt.gcf()
ax1 = plt.subplot2grid((1, 6), (0, 0))
ax2 = plt.subplot2grid((1, 6), (0, 1))
ax3 = plt.subplot2grid((1, 6), (0, 2))

set_style()
relevant_color = '#f79646'
irrelevant_color = '#008080'

##### Table #####
ax1.set_title(r'$\beta_{table}$', fontsize=16, fontweight='normal')
r1 = ax1.bar([0.0], 
             [t_t.mean()], 
             yerr=[t_t.sem()], 
             color=[relevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax1.bar([1.0], 
             [t_c.mean()], 
             yerr=[t_c.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r3 = ax1.bar([2.0], 
             [t_h.mean()], 
             yerr=[t_h.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r4 = ax1.bar([3.0], 
             [t_a.mean()], 
             yerr=[t_a.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax1, 0, 1, 1.65, 0.08)
ax1.set_ylim([0, 1.7])
#ax1.set_xlim([-0.25, 2.25])
plt.sca(ax1)
plt.xticks([])
# ax1.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Coffee #####
ax2.set_title(r'$\beta_{cup}$', fontsize=16, fontweight='normal')
r1 = ax2.bar([0.0], 
             [c_t.mean()], 
             yerr=[c_t.sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax2.bar([1.0], 
             [c_c.mean()], 
             yerr=[c_c.sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r3 = ax2.bar([2.0], 
             [c_h.mean()], 
             yerr=[c_h.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r4 = ax2.bar([3.0], 
             [c_a.mean()], 
             yerr=[c_a.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax2, 0, 1, 1.525, 0.08)
ax2.set_ylim([0, 1.7])
#ax2.set_xlim([-0.25, 2.25])
plt.sca(ax2)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

##### Human #####
ax3.set_title(r'$\beta_{human}$', fontsize=16, fontweight='normal')
r1 = ax3.bar([0.0], 
             [h_t.mean()], 
             yerr=[t_h.sem()], 
             color=[irrelevant_color], 
             ecolor='black', 
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax3.bar([1.0], 
             [h_c.mean()], 
             yerr=[h_c.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r2 = ax3.bar([2.0], 
             [h_h.mean()], 
             yerr=[h_h.sem()], 
             color=[relevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
r4 = ax3.bar([3.0], 
             [h_a.mean()], 
             yerr=[h_a.sem()], 
             color=[irrelevant_color], 
             ecolor='black',
             width=1.0,
             error_kw=dict(elinewidth=2, capsize=0))
#plot_sig_line(ax3, 0, 1, 1.6, 0.07)
ax3.set_ylim([0, 1.7])
#ax3.set_xlim([-0.25, 2.25])
plt.sca(ax3)
plt.xticks([])
# ax2.set_ylabel('time (s)', fontsize=16, fontweight='normal')
################

#leg = ax3.legend((r1[0], r2[0], r3[0]), 
#                ('Table $u_H$', 'Coffee $u_H$', 'Human $u_H$'), 
#                loc='upper right',
#                ncol=1, 
#                fontsize=11,
#                bbox_to_anchor=(2., 1.0))

plt.subplots_adjust(wspace=0.35)

sns.despine(fig)
fig.set_figwidth(15)
fig.set_figheight(4)

plt.savefig('features_split_barplots.pdf', bbox_inches='tight')
